# %%
# Cài đặt các thư viện cần thiết
# !pip install torch torchvision pandas nibabel SimpleITK scikit-image
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.20.1+cu124)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.3)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (5.3.2)
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel) (6.5.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from nibabel) (24.2)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.15.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.1 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.6 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcugraph-cu12 24.12.0 requires pylibraft-cu12==24.12.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 24.12.0 requires rmm-cu12==24.12.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import os
import time
import random
import zipfile
import shutil
import gdown
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
from scipy.ndimage import zoom
from collections import defaultdict

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# Kiểm tra GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Thiết bị đang sử dụng: {device}")

# Tải file từ Google Drive
url = "https://drive.google.com/uc?id=1YHVACL9CIhVFrZ-MnhuDoYNdQBH-lkGJ"
output = "/kaggle/working/data_processed.zip"
gdown.download(url, output, quiet=False)

# Giải nén file
extract_dir = "/kaggle/working/"
with zipfile.ZipFile(output, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)
print("Đã giải nén file data_processed.zip")
# Out:
# Thiết bị đang sử dụng: cuda
# Downloading...
# From (original): https://drive.google.com/uc?id=1YHVACL9CIhVFrZ-MnhuDoYNdQBH-lkGJ
# From (redirected): https://drive.google.com/uc?id=1YHVACL9CIhVFrZ-MnhuDoYNdQBH-lkGJ&confirm=t&uuid=e0927d02-90ed-444a-834c-51d148de3237
# To: /kaggle/working/data_processed.zip
# 100%|██████████| 2.60G/2.60G [00:33<00:00, 77.2MB/s]
# Đã giải nén file data_processed.zip

# %%
# Đọc file participants.xlsx
participants_file = "/kaggle/working/data_processed/participants.xlsx"
participants_df = pd.read_excel(participants_file)

# Tạo dictionary ánh xạ subject_id
subject_info = {}
for _, row in participants_df.iterrows():
    subject_id = row['subject_id']
    subject_info[subject_id] = {
        'age': float(row['subject_age']),
        'gender': 1 if row['subject_sex'] == 'm' else 0
    }
print(f"Tổng số subject trong participants.xlsx: {len(subject_info)}")

# Thu thập danh sách file .nii.gz
data_base_dir = "/kaggle/working/data_processed"
file_list = []
ages = []
genders = []
missing_subjects = []

for sub_dir in os.listdir(data_base_dir):
    if not sub_dir.startswith('sub-BrainAge'):
        continue
    sub_dir_path = os.path.join(data_base_dir, sub_dir, "anat")
    if not os.path.exists(sub_dir_path):
        continue
    for file in os.listdir(sub_dir_path):
        if file.endswith('.nii.gz'):
            file_path = os.path.join(sub_dir_path, file)
            file_list.append(file_path)
            subject_id = sub_dir
            if subject_id in subject_info:
                age = subject_info[subject_id]['age']
                gender = subject_info[subject_id]['gender']
                ages.append(age)
                genders.append(gender)
            else:
                missing_subjects.append((file_path, subject_id))

print(f"Tổng số file .nii.gz tìm thấy: {len(file_list)}")
print(f"Số file không tìm thấy thông tin: {len(missing_subjects)}")

# Chuẩn hóa tuổi
max_age = 100
ages_normalized = np.array(ages) / max_age
# Out:
# Tổng số subject trong participants.xlsx: 4950
# Tổng số file .nii.gz tìm thấy: 3000
# Số file không tìm thấy thông tin: 0

# %%
# Hàm tiền xử lý ảnh 2D (bỏ skull-stripping vì dữ liệu đã được xử lý)
def preprocess_mri_slice(mri_slice):
    # Intensity normalization
    mri_normalized = (mri_slice - mri_slice.min()) / (mri_slice.max() - mri_slice.min())
    return mri_normalized

# Xử lý và lưu 3 mặt cắt
output_base_dir = "/kaggle/working/processed_mri_slices"
os.makedirs(output_base_dir, exist_ok=True)
shutil.copy(participants_file, os.path.join(output_base_dir, "participants.xlsx"))

for idx, file_path in enumerate(file_list):
    subject_id = os.path.basename(os.path.dirname(os.path.dirname(file_path)))
    subject_output_dir = os.path.join(output_base_dir, subject_id, "anat")
    os.makedirs(subject_output_dir, exist_ok=True)
    
    # Đọc ảnh 3D
    mri_img = nib.load(file_path)
    mri_data = mri_img.get_fdata()  # Shape: (130, 130, 130)
    
    # Lấy 3 mặt cắt giữa
    axial_idx = mri_data.shape[2] // 2
    coronal_idx = mri_data.shape[1] // 2
    sagittal_idx = mri_data.shape[0] // 2
    
    axial_slice = mri_data[:, :, axial_idx]  # Shape: (130, 130)
    coronal_slice = mri_data[:, coronal_idx, :]  # Shape: (130, 130)
    sagittal_slice = mri_data[sagittal_idx, :, :]  # Shape: (130, 130)
    
    # Cắt 1 pixel mỗi chiều
    axial_slice = axial_slice[1:-1, 1:-1]  # Shape: (128, 128)
    coronal_slice = coronal_slice[1:-1, 1:-1]
    sagittal_slice = sagittal_slice[1:-1, 1:-1]
    
    # Tiền xử lý
    axial_normalized = preprocess_mri_slice(axial_slice)
    coronal_normalized = preprocess_mri_slice(coronal_slice)
    sagittal_normalized = preprocess_mri_slice(sagittal_slice)
    
    # Resize về (64, 64)
    target_shape = (64, 64)
    axial_resized = zoom(axial_normalized, [t / s for t, s in zip(target_shape, axial_normalized.shape)], order=1)
    coronal_resized = zoom(coronal_normalized, [t / s for t, s in zip(target_shape, coronal_normalized.shape)], order=1)
    sagittal_resized = zoom(sagittal_normalized, [t / s for t, s in zip(target_shape, sagittal_normalized.shape)], order=1)
    
    # Chuẩn hóa về [-1, 1]
    axial_final = axial_resized * 2 - 1
    coronal_final = coronal_resized * 2 - 1
    sagittal_final = sagittal_resized * 2 - 1
    
    # Lưu 3 mặt cắt
    for slice_type, slice_data in [
        ('axial', axial_final),
        ('coronal', coronal_final),
        ('sagittal', sagittal_final)
    ]:
        output_file = os.path.join(subject_output_dir, f"{subject_id}_T1w_{slice_type}.nii.gz")
        slice_data_3d = slice_data[np.newaxis, :, :]  # Shape: (1, 64, 64)
        nib.save(nib.Nifti1Image(slice_data_3d, np.eye(4)), output_file)
print(f"Đã lưu tất cả dữ liệu vào: {output_base_dir}")

# Vẽ ví dụ 3 mặt cắt của subject đầu tiên
sample_file = file_list[0]
subject_id = os.path.basename(os.path.dirname(os.path.dirname(sample_file)))
mri_img = nib.load(sample_file)
mri_data = mri_img.get_fdata()
axial_idx = mri_data.shape[2] // 2
coronal_idx = mri_data.shape[1] // 2
sagittal_idx = mri_data.shape[0] // 2
axial_slice = mri_data[:, :, axial_idx][1:-1, 1:-1]
coronal_slice = mri_data[:, coronal_idx, :][1:-1, 1:-1]
sagittal_slice = mri_data[sagittal_idx, :, :][1:-1, 1:-1]
axial_normalized = preprocess_mri_slice(axial_slice)
coronal_normalized = preprocess_mri_slice(coronal_slice)
sagittal_normalized = preprocess_mri_slice(sagittal_slice)
axial_final = zoom(axial_normalized, [64 / s for s in axial_normalized.shape], order=1)
coronal_final = zoom(coronal_normalized, [64 / s for s in coronal_normalized.shape], order=1)
sagittal_final = zoom(sagittal_normalized, [64 / s for s in sagittal_normalized.shape], order=1)

plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title("Axial (64x64)")
plt.imshow(axial_final, cmap='gray')
plt.axis('off')
plt.subplot(1, 3, 2)
plt.title("Coronal (64x64)")
plt.imshow(coronal_final, cmap='gray')
plt.axis('off')
plt.subplot(1, 3, 3)
plt.title("Sagittal (64x64)")
plt.imshow(sagittal_final, cmap='gray')
plt.axis('off')
plt.tight_layout()
plt.savefig('/kaggle/working/sample_slices.png')
plt.show()
plt.close()
# Out:
# Đã lưu tất cả dữ liệu vào: /kaggle/working/processed_mri_slices

# %%
# Đọc participants.xlsx
participants_file = "/kaggle/working/processed_mri_slices/participants.xlsx"
participants_df = pd.read_excel(participants_file)
subject_info = {}
for _, row in participants_df.iterrows():
    subject_id = row['subject_id']
    subject_info[subject_id] = {
        'age': float(row['subject_age']),
        'gender': 1 if row['subject_sex'] == 'm' else 0
    }

# Tạo chỉ mục cho truy vấn real_B
subjects = [s for s in os.listdir("/kaggle/working/processed_mri_slices") if s.startswith('sub-BrainAge')]
ages = [subject_info[s]['age'] for s in subjects]
genders = [subject_info[s]['gender'] for s in subjects]
ages_normalized = np.array(ages) / 100
condition_cache = defaultdict(list)
for idx, subject_id in enumerate(subjects):
    age = int(ages[idx])
    gender = genders[idx]
    condition_cache[(age, gender)].append(idx)

# %%
# Dataset với preload
class MRIDataset(Dataset):
    def __init__(self, data_dir, subjects, subject_info, target_shape=(64, 64)):
        self.data_dir = data_dir
        self.subjects = subjects
        self.subject_info = subject_info
        self.target_shape = target_shape
        self.data = []
        
        # Preload dữ liệu
        print("Preloading dataset...")
        for subject_id in subjects:
            subject_dir = os.path.join(data_dir, subject_id, "anat")
            slices = []
            for slice_type in ['axial', 'coronal', 'sagittal']:
                file_path = os.path.join(subject_dir, f"{subject_id}_T1w_{slice_type}.nii.gz")
                mri_img = nib.load(file_path)
                mri_data = mri_img.get_fdata()[0]  # Shape: (64, 64)
                slices.append(mri_data)
            mri_tensor = torch.tensor(np.stack(slices), dtype=torch.float32)  # Shape: (3, 64, 64)
            age = subject_info[subject_id]['age'] / 100
            gender = subject_info[subject_id]['gender']
            condition = torch.tensor([age, gender], dtype=torch.float32)
            self.data.append((mri_tensor, condition))
        print("Dataset preloaded.")
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return self.data[idx]

# Hàm truy vấn ảnh (từ cache dataset)
def get_image_and_condition(idx, dataset):
    mri_tensor, condition = dataset[idx]
    return mri_tensor.to(device), condition.to(device)

# Tạo Dataset và DataLoader
data_dir = "/kaggle/working/processed_mri_slices"
dataset = MRIDataset(data_dir, subjects, subject_info, target_shape=(64, 64))
dataloader = DataLoader(dataset, batch_size=128, shuffle=True, num_workers=4, pin_memory=True)  # Tăng batch size
# Out:
# Preloading dataset...
# Dataset preloaded.

# %%
# Generator
class Generator(nn.Module):
    def __init__(self, condition_dim=4):
        super(Generator, self).__init__()
        self.condition_dim = condition_dim
        self.condition_layer = nn.Sequential(
            nn.Linear(condition_dim, 64),
            nn.ReLU(),
        )
        self.encoder = nn.Sequential(
            nn.Conv2d(4, 64, kernel_size=4, stride=2, padding=1),  # Input: 3 kênh ảnh + 1 kênh condition
            nn.LeakyReLU(0.2),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2),
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1),  # Output: 3 kênh
            nn.Tanh(),
        )
    
    def forward(self, x, condition):
        batch_size = x.size(0)
        condition = condition[:batch_size]
        condition = self.condition_layer(condition)
        condition = condition.view(batch_size, 1, 64, 1).expand(batch_size, 1, 64, 64)
        x = torch.cat([x, condition], dim=1)  # Shape: (batch_size, 4, 64, 64)
        x = self.encoder(x)
        x = self.decoder(x)  # Shape: (batch_size, 3, 64, 64)
        return x

# Discriminator
class Discriminator(nn.Module):
    def __init__(self, condition_dim=2):
        super(Discriminator, self).__init__()
        self.condition_dim = condition_dim
        self.condition_layer = nn.Sequential(
            nn.Linear(condition_dim, 64),
            nn.ReLU(),
        )
        self.model = nn.Sequential(
            nn.Conv2d(4, 64, kernel_size=4, stride=2, padding=1),  # Input: 3 kênh ảnh + 1 kênh condition
            nn.LeakyReLU(0.2),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2),
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2),
            nn.Flatten(),
            nn.Linear(256 * 8 * 8, 1),
        )
    
    def forward(self, x, condition):
        batch_size = x.size(0)
        condition = condition[:batch_size]
        condition = self.condition_layer(condition)
        condition = condition.view(batch_size, 1, 64, 1).expand(batch_size, 1, 64, 64)
        x = torch.cat([x, condition], dim=1)  # Shape: (batch_size, 4, 64, 64)
        x = self.model(x)
        return x

# %%
# Khởi tạo mô hình
G_A_to_B = Generator().to(device)
G_B_to_A = Generator().to(device)
D_A = Discriminator().to(device)
D_B = Discriminator().to(device)

# Loss functions và optimizers
adversarial_loss = nn.BCEWithLogitsLoss()
cycle_loss_fn = nn.L1Loss()
optimizer_G = optim.Adam(list(G_A_to_B.parameters()) + list(G_B_to_A.parameters()), lr=0.0002, betas=(0.5, 0.999))
optimizer_D_A = optim.Adam(D_A.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizer_D_B = optim.Adam(D_B.parameters(), lr=0.0002, betas=(0.5, 0.999))

# Mixed precision
scaler = torch.amp.GradScaler('cuda')
# Huấn luyện

# Huấn luyện
epochs = 400
max_age = 100

for epoch in range(epochs):
    d_a_losses = []
    d_b_losses = []
    g_losses = []
    num_batches = 0
    data_time = 0
    model_time = 0
    query_time = 0
    
    for i, (real_A, condition_A) in enumerate(dataloader):
        start_time = time.time()
        real_A = real_A.to(device)  # Shape: (batch_size, 3, 64, 64)
        condition_A = condition_A.to(device)
        data_time += time.time() - start_time
        
        batch_size = real_A.size(0)
        
        # Chọn tuổi và giới tính đích ngẫu nhiên
        target_age = torch.randint(0, int(max_age) + 1, (batch_size,), device=device).float()
        target_age_normalized = target_age / max_age
        target_gender = torch.randint(0, 2, (batch_size,), device=device).float()
        condition_A_to_B = torch.stack([condition_A[:, 0], condition_A[:, 1], target_age_normalized, target_gender], dim=1)
        
        # Chọn real_B từ cache
        query_start = time.time()
        idx_B_list = []
        for j in range(batch_size):
            target_age_i = int(target_age[j].item())
            target_gender_i = int(target_gender[j].item())
            candidates = []
            for age_diff in range(11):
                for age in [target_age_i - age_diff, target_age_i + age_diff]:
                    candidates.extend(condition_cache.get((age, target_gender_i), []))
            if not candidates:
                age_diffs = [
                    (abs(ages[idx] - target_age_i) + (genders[idx] != target_gender_i) * 1000, idx)
                    for idx in range(len(subjects))
                ]
                age_diffs.sort()
                candidates = [age_diffs[0][1]]
            idx_B = random.choice(candidates)
            idx_B_list.append(idx_B)
        
        # Song song hóa truy vấn real_B
        real_B_list = []
        condition_B_list = []
        for idx_B in idx_B_list:
            real_B_i, condition_B_i = get_image_and_condition(idx_B, dataset)
            real_B_list.append(real_B_i.unsqueeze(0))
            condition_B_list.append(condition_B_i)
        real_B = torch.cat(real_B_list, dim=0)
        condition_B = torch.stack([target_age_normalized, target_gender], dim=1)
        condition_B_to_A = torch.cat([condition_B[:, :2], condition_A[:, :2]], dim=1)
        query_time += time.time() - query_start
        
        # Huấn luyện Discriminator
        optimizer_D_A.zero_grad()
        optimizer_D_B.zero_grad()
        
        model_start = time.time()
        with torch.amp.autocast('cuda'):
            real_A_output = D_A(real_A, condition_A)
            fake_B = G_A_to_B(real_A, condition_A_to_B)
            fake_A = G_B_to_A(real_B, condition_B_to_A)
            fake_A_output = D_A(fake_A.detach(), condition_A)
            
            d_A_loss_real = adversarial_loss(real_A_output, torch.ones_like(real_A_output))
            d_A_loss_fake = adversarial_loss(fake_A_output, torch.zeros_like(fake_A_output))
            d_A_loss = (d_A_loss_real + d_A_loss_fake) * 0.5
            
            real_B_output = D_B(real_B, condition_B)
            fake_B_output = D_B(fake_B.detach(), condition_B)
            d_B_loss_real = adversarial_loss(real_B_output, torch.ones_like(real_B_output))
            d_B_loss_fake = adversarial_loss(fake_B_output, torch.zeros_like(fake_B_output))
            d_B_loss = (d_B_loss_real + d_B_loss_fake) * 0.5
        
        scaler.scale(d_A_loss).backward()
        scaler.scale(d_B_loss).backward()
        scaler.step(optimizer_D_A)
        scaler.step(optimizer_D_B)
        
        # Huấn luyện Generator
        optimizer_G.zero_grad()
        with torch.amp.autocast('cuda'):
            fake_B = G_A_to_B(real_A, condition_A_to_B)
            fake_A = G_B_to_A(real_B, condition_B_to_A)
            fake_B_output = D_B(fake_B, condition_B)
            fake_A_output = D_A(fake_A, condition_A)
            cycled_A = G_B_to_A(fake_B, condition_B_to_A)
            cycled_B = G_A_to_B(fake_A, condition_A_to_B)
            g_A_to_B_loss = adversarial_loss(fake_B_output, torch.ones_like(fake_B_output))
            g_B_to_A_loss = adversarial_loss(fake_A_output, torch.ones_like(fake_A_output))
            cycle_A_loss = cycle_loss_fn(real_A, cycled_A)
            cycle_B_loss = cycle_loss_fn(real_B, cycled_B)
            total_g_loss = g_A_to_B_loss + g_B_to_A_loss + 7.0 * (cycle_A_loss + cycle_B_loss)  # Giảm trọng số cycle loss
        
        scaler.scale(total_g_loss).backward()
        scaler.step(optimizer_G)
        scaler.update()
        model_time += time.time() - model_start
        
        d_a_losses.append(d_A_loss.item())
        d_b_losses.append(d_B_loss.item())
        g_losses.append(total_g_loss.item())
        num_batches += 1
        
        if i % 100 == 0:
            torch.save(G_A_to_B.state_dict(), f"/kaggle/working/G_A_to_B_epoch_{epoch}_batch_{i}.pth")
            torch.save(G_B_to_A.state_dict(), f"/kaggle/working/G_B_to_A_epoch_{epoch}_batch_{i}.pth")
            print(f"Batch {i}, Data time: {data_time:.2f}s, Query time: {query_time:.2f}s, Model time: {model_time:.2f}s, VRAM: {torch.cuda.memory_allocated() / 1024**2:.2f}MB")
    
    avg_d_a_loss = sum(d_a_losses) / num_batches if num_batches > 0 else 0
    avg_d_b_loss = sum(d_b_losses) / num_batches if num_batches > 0 else 0
    avg_g_loss = sum(g_losses) / num_batches if num_batches > 0 else 0
    print(f"Epoch {epoch+1}, Avg D_A Loss: {avg_d_a_loss:.4f}, Avg D_B Loss: {avg_d_b_loss:.4f}, Avg G Loss: {avg_g_loss:.4f}")
# Out:
# Batch 0, Data time: 0.00s, Query time: 0.11s, Model time: 0.86s, VRAM: 91.98MB
# Epoch 1, Avg D_A Loss: 0.5293, Avg D_B Loss: 0.5089, Avg G Loss: 12.0179
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.68MB
# Epoch 2, Avg D_A Loss: 0.6162, Avg D_B Loss: 0.6359, Avg G Loss: 4.8357
# Batch 0, Data time: 0.00s, Query time: 0.08s, Model time: 0.26s, VRAM: 110.80MB
# Epoch 3, Avg D_A Loss: 0.5448, Avg D_B Loss: 0.5789, Avg G Loss: 4.2379
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.43MB
# Epoch 4, Avg D_A Loss: 0.5686, Avg D_B Loss: 0.5905, Avg G Loss: 4.2827
# Batch 0, Data time: 0.00s, Query time: 0.08s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 5, Avg D_A Loss: 0.6465, Avg D_B Loss: 0.6450, Avg G Loss: 4.0550
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.55MB
# Epoch 6, Avg D_A Loss: 0.6512, Avg D_B Loss: 0.6441, Avg G Loss: 4.0112
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 7, Avg D_A Loss: 0.6857, Avg D_B Loss: 0.6829, Avg G Loss: 3.8385
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.24MB
# Epoch 8, Avg D_A Loss: 0.6556, Avg D_B Loss: 0.6710, Avg G Loss: 3.6148
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.30MB
# Epoch 9, Avg D_A Loss: 0.6748, Avg D_B Loss: 0.6873, Avg G Loss: 3.6195
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 10, Avg D_A Loss: 0.6634, Avg D_B Loss: 0.6659, Avg G Loss: 3.5776
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 113.86MB
# Epoch 11, Avg D_A Loss: 0.6787, Avg D_B Loss: 0.6993, Avg G Loss: 3.6627
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 113.11MB
# Epoch 12, Avg D_A Loss: 0.6622, Avg D_B Loss: 0.6644, Avg G Loss: 3.5159
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 13, Avg D_A Loss: 0.6414, Avg D_B Loss: 0.6603, Avg G Loss: 3.5833
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.30MB
# Epoch 14, Avg D_A Loss: 0.6352, Avg D_B Loss: 0.6588, Avg G Loss: 3.7641
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 113.55MB
# Epoch 15, Avg D_A Loss: 0.6650, Avg D_B Loss: 0.6506, Avg G Loss: 3.7652
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.49MB
# Epoch 16, Avg D_A Loss: 0.6591, Avg D_B Loss: 0.6528, Avg G Loss: 3.6700
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.36MB
# Epoch 17, Avg D_A Loss: 0.6549, Avg D_B Loss: 0.6585, Avg G Loss: 3.7354
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.93MB
# Epoch 18, Avg D_A Loss: 0.6522, Avg D_B Loss: 0.6547, Avg G Loss: 3.8044
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 19, Avg D_A Loss: 0.6365, Avg D_B Loss: 0.6631, Avg G Loss: 3.7497
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 20, Avg D_A Loss: 0.6269, Avg D_B Loss: 0.6526, Avg G Loss: 3.7265
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 21, Avg D_A Loss: 0.6293, Avg D_B Loss: 0.6493, Avg G Loss: 3.6927
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.86MB
# Epoch 22, Avg D_A Loss: 0.6230, Avg D_B Loss: 0.6406, Avg G Loss: 3.6795
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 114.30MB
# Epoch 23, Avg D_A Loss: 0.6317, Avg D_B Loss: 0.6398, Avg G Loss: 3.7095
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.55MB
# Epoch 24, Avg D_A Loss: 0.6485, Avg D_B Loss: 0.6175, Avg G Loss: 3.6619
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 25, Avg D_A Loss: 0.6626, Avg D_B Loss: 0.6219, Avg G Loss: 3.6966
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 26, Avg D_A Loss: 0.6538, Avg D_B Loss: 0.6327, Avg G Loss: 3.6135
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 27, Avg D_A Loss: 0.6600, Avg D_B Loss: 0.6296, Avg G Loss: 3.6823
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 28, Avg D_A Loss: 0.6563, Avg D_B Loss: 0.6188, Avg G Loss: 3.5754
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 29, Avg D_A Loss: 0.6452, Avg D_B Loss: 0.6402, Avg G Loss: 3.6293
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 30, Avg D_A Loss: 0.6475, Avg D_B Loss: 0.6268, Avg G Loss: 3.5980
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.68MB
# Epoch 31, Avg D_A Loss: 0.6518, Avg D_B Loss: 0.6446, Avg G Loss: 3.6099
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 32, Avg D_A Loss: 0.6462, Avg D_B Loss: 0.6314, Avg G Loss: 3.5886
# Batch 0, Data time: 0.00s, Query time: 0.03s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 33, Avg D_A Loss: 0.6487, Avg D_B Loss: 0.6454, Avg G Loss: 3.5868
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 34, Avg D_A Loss: 0.6586, Avg D_B Loss: 0.6283, Avg G Loss: 3.5273
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 35, Avg D_A Loss: 0.6462, Avg D_B Loss: 0.6319, Avg G Loss: 3.5873
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.49MB
# Epoch 36, Avg D_A Loss: 0.6569, Avg D_B Loss: 0.6431, Avg G Loss: 3.5608
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 114.05MB
# Epoch 37, Avg D_A Loss: 0.6468, Avg D_B Loss: 0.6373, Avg G Loss: 3.5053
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 38, Avg D_A Loss: 0.6513, Avg D_B Loss: 0.6265, Avg G Loss: 3.5175
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 39, Avg D_A Loss: 0.6491, Avg D_B Loss: 0.6284, Avg G Loss: 3.5558
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 40, Avg D_A Loss: 0.6401, Avg D_B Loss: 0.6186, Avg G Loss: 3.5545
# Batch 0, Data time: 0.00s, Query time: 0.08s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 41, Avg D_A Loss: 0.6604, Avg D_B Loss: 0.6280, Avg G Loss: 3.6225
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 42, Avg D_A Loss: 0.6368, Avg D_B Loss: 0.6227, Avg G Loss: 3.5746
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 43, Avg D_A Loss: 0.6448, Avg D_B Loss: 0.6133, Avg G Loss: 3.5495
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 44, Avg D_A Loss: 0.6343, Avg D_B Loss: 0.6200, Avg G Loss: 3.6110
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 109.68MB
# Epoch 45, Avg D_A Loss: 0.6434, Avg D_B Loss: 0.6224, Avg G Loss: 3.6501
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 46, Avg D_A Loss: 0.6262, Avg D_B Loss: 0.6219, Avg G Loss: 3.6093
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 47, Avg D_A Loss: 0.6392, Avg D_B Loss: 0.6150, Avg G Loss: 3.6310
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 112.99MB
# Epoch 48, Avg D_A Loss: 0.6311, Avg D_B Loss: 0.6166, Avg G Loss: 3.6311
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.55MB
# Epoch 49, Avg D_A Loss: 0.6300, Avg D_B Loss: 0.6252, Avg G Loss: 3.6452
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 112.43MB
# Epoch 50, Avg D_A Loss: 0.6169, Avg D_B Loss: 0.6067, Avg G Loss: 3.6723
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 51, Avg D_A Loss: 0.6177, Avg D_B Loss: 0.6047, Avg G Loss: 3.7227
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.36MB
# Epoch 52, Avg D_A Loss: 0.6139, Avg D_B Loss: 0.6109, Avg G Loss: 3.7395
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 53, Avg D_A Loss: 0.6159, Avg D_B Loss: 0.5914, Avg G Loss: 3.8074
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.36MB
# Epoch 54, Avg D_A Loss: 0.6264, Avg D_B Loss: 0.5928, Avg G Loss: 3.8429
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.36MB
# Epoch 55, Avg D_A Loss: 0.6249, Avg D_B Loss: 0.5729, Avg G Loss: 3.8127
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 56, Avg D_A Loss: 0.6111, Avg D_B Loss: 0.5770, Avg G Loss: 3.9210
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.36MB
# Epoch 57, Avg D_A Loss: 0.6107, Avg D_B Loss: 0.5899, Avg G Loss: 3.9349
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.43MB
# Epoch 58, Avg D_A Loss: 0.6105, Avg D_B Loss: 0.5911, Avg G Loss: 3.9292
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 59, Avg D_A Loss: 0.6127, Avg D_B Loss: 0.5797, Avg G Loss: 3.9698
# Batch 0, Data time: 0.00s, Query time: 0.03s, Model time: 0.26s, VRAM: 112.05MB
# Epoch 60, Avg D_A Loss: 0.6051, Avg D_B Loss: 0.5786, Avg G Loss: 3.8865
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 61, Avg D_A Loss: 0.6011, Avg D_B Loss: 0.5687, Avg G Loss: 3.9553
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 62, Avg D_A Loss: 0.5899, Avg D_B Loss: 0.5748, Avg G Loss: 3.9909
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 113.05MB
# Epoch 63, Avg D_A Loss: 0.6136, Avg D_B Loss: 0.5658, Avg G Loss: 4.0900
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.18MB
# Epoch 64, Avg D_A Loss: 0.6140, Avg D_B Loss: 0.5838, Avg G Loss: 4.0791
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.86MB
# Epoch 65, Avg D_A Loss: 0.6079, Avg D_B Loss: 0.5631, Avg G Loss: 4.0682
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 115.11MB
# Epoch 66, Avg D_A Loss: 0.5973, Avg D_B Loss: 0.5497, Avg G Loss: 4.0194
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 67, Avg D_A Loss: 0.6035, Avg D_B Loss: 0.5605, Avg G Loss: 4.0554
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 68, Avg D_A Loss: 0.6146, Avg D_B Loss: 0.5554, Avg G Loss: 4.1060
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 115.24MB
# Epoch 69, Avg D_A Loss: 0.6024, Avg D_B Loss: 0.5535, Avg G Loss: 4.0811
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.36MB
# Epoch 70, Avg D_A Loss: 0.6005, Avg D_B Loss: 0.5421, Avg G Loss: 4.0882
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 71, Avg D_A Loss: 0.5902, Avg D_B Loss: 0.5389, Avg G Loss: 4.1519
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 72, Avg D_A Loss: 0.6003, Avg D_B Loss: 0.5486, Avg G Loss: 4.1773
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 73, Avg D_A Loss: 0.5833, Avg D_B Loss: 0.5184, Avg G Loss: 4.2092
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 74, Avg D_A Loss: 0.5770, Avg D_B Loss: 0.5384, Avg G Loss: 4.3261
# Batch 0, Data time: 0.00s, Query time: 0.37s, Model time: 0.26s, VRAM: 110.68MB
# Epoch 75, Avg D_A Loss: 0.5980, Avg D_B Loss: 0.5677, Avg G Loss: 4.3342
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.43MB
# Epoch 76, Avg D_A Loss: 0.6092, Avg D_B Loss: 0.5266, Avg G Loss: 4.3579
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.49MB
# Epoch 77, Avg D_A Loss: 0.5835, Avg D_B Loss: 0.5282, Avg G Loss: 4.3616
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 78, Avg D_A Loss: 0.5806, Avg D_B Loss: 0.5401, Avg G Loss: 4.3353
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 113.49MB
# Epoch 79, Avg D_A Loss: 0.5893, Avg D_B Loss: 0.5468, Avg G Loss: 4.2432
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 113.11MB
# Epoch 80, Avg D_A Loss: 0.5921, Avg D_B Loss: 0.5484, Avg G Loss: 4.1878
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 81, Avg D_A Loss: 0.5695, Avg D_B Loss: 0.5667, Avg G Loss: 4.2717
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.55MB
# Epoch 82, Avg D_A Loss: 0.5675, Avg D_B Loss: 0.5724, Avg G Loss: 4.2807
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 83, Avg D_A Loss: 0.5671, Avg D_B Loss: 0.5551, Avg G Loss: 4.2750
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 84, Avg D_A Loss: 0.5718, Avg D_B Loss: 0.5409, Avg G Loss: 4.3117
# Batch 0, Data time: 0.00s, Query time: 0.33s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 85, Avg D_A Loss: 0.5683, Avg D_B Loss: 0.5611, Avg G Loss: 4.2951
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 86, Avg D_A Loss: 0.5732, Avg D_B Loss: 0.5806, Avg G Loss: 4.3416
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 87, Avg D_A Loss: 0.5731, Avg D_B Loss: 0.5667, Avg G Loss: 4.3654
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 88, Avg D_A Loss: 0.5733, Avg D_B Loss: 0.5522, Avg G Loss: 4.2448
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.68MB
# Epoch 89, Avg D_A Loss: 0.5743, Avg D_B Loss: 0.5544, Avg G Loss: 4.3410
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 90, Avg D_A Loss: 0.5610, Avg D_B Loss: 0.5450, Avg G Loss: 4.3898
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 91, Avg D_A Loss: 0.5666, Avg D_B Loss: 0.5663, Avg G Loss: 4.4622
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 92, Avg D_A Loss: 0.5673, Avg D_B Loss: 0.5471, Avg G Loss: 4.4864
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 93, Avg D_A Loss: 0.5782, Avg D_B Loss: 0.5532, Avg G Loss: 4.3822
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.49MB
# Epoch 94, Avg D_A Loss: 0.5539, Avg D_B Loss: 0.5588, Avg G Loss: 4.3017
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 114.05MB
# Epoch 95, Avg D_A Loss: 0.5801, Avg D_B Loss: 0.5422, Avg G Loss: 4.4203
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 96, Avg D_A Loss: 0.5755, Avg D_B Loss: 0.5451, Avg G Loss: 4.4114
# Batch 0, Data time: 0.01s, Query time: 0.09s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 97, Avg D_A Loss: 0.5715, Avg D_B Loss: 0.5641, Avg G Loss: 4.3705
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 98, Avg D_A Loss: 0.5780, Avg D_B Loss: 0.5299, Avg G Loss: 4.3819
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 99, Avg D_A Loss: 0.5846, Avg D_B Loss: 0.5576, Avg G Loss: 4.4292
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 100, Avg D_A Loss: 0.5815, Avg D_B Loss: 0.5388, Avg G Loss: 4.3951
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 101, Avg D_A Loss: 0.5858, Avg D_B Loss: 0.5284, Avg G Loss: 4.3757
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 102, Avg D_A Loss: 0.5933, Avg D_B Loss: 0.5418, Avg G Loss: 4.3752
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 109.68MB
# Epoch 103, Avg D_A Loss: 0.5750, Avg D_B Loss: 0.5429, Avg G Loss: 4.3536
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 104, Avg D_A Loss: 0.5839, Avg D_B Loss: 0.5526, Avg G Loss: 4.3174
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 105, Avg D_A Loss: 0.5808, Avg D_B Loss: 0.5601, Avg G Loss: 4.3003
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.99MB
# Epoch 106, Avg D_A Loss: 0.5771, Avg D_B Loss: 0.5533, Avg G Loss: 4.3547
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.55MB
# Epoch 107, Avg D_A Loss: 0.5619, Avg D_B Loss: 0.5501, Avg G Loss: 4.3150
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.43MB
# Epoch 108, Avg D_A Loss: 0.5783, Avg D_B Loss: 0.5411, Avg G Loss: 4.2872
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 109, Avg D_A Loss: 0.5679, Avg D_B Loss: 0.5337, Avg G Loss: 4.3469
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 110.36MB
# Epoch 110, Avg D_A Loss: 0.5775, Avg D_B Loss: 0.5411, Avg G Loss: 4.4369
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 111, Avg D_A Loss: 0.5829, Avg D_B Loss: 0.5274, Avg G Loss: 4.3038
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.36MB
# Epoch 112, Avg D_A Loss: 0.5688, Avg D_B Loss: 0.5426, Avg G Loss: 4.4440
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.36MB
# Epoch 113, Avg D_A Loss: 0.5721, Avg D_B Loss: 0.5296, Avg G Loss: 4.4491
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 114, Avg D_A Loss: 0.5685, Avg D_B Loss: 0.5340, Avg G Loss: 4.4402
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.36MB
# Epoch 115, Avg D_A Loss: 0.5863, Avg D_B Loss: 0.5323, Avg G Loss: 4.4636
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.43MB
# Epoch 116, Avg D_A Loss: 0.5682, Avg D_B Loss: 0.5162, Avg G Loss: 4.3520
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 117, Avg D_A Loss: 0.5711, Avg D_B Loss: 0.5280, Avg G Loss: 4.4316
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.05MB
# Epoch 118, Avg D_A Loss: 0.5726, Avg D_B Loss: 0.5156, Avg G Loss: 4.3913
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 119, Avg D_A Loss: 0.5634, Avg D_B Loss: 0.5170, Avg G Loss: 4.3207
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 120, Avg D_A Loss: 0.5586, Avg D_B Loss: 0.5221, Avg G Loss: 4.3176
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 113.05MB
# Epoch 121, Avg D_A Loss: 0.5769, Avg D_B Loss: 0.5296, Avg G Loss: 4.3776
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.18MB
# Epoch 122, Avg D_A Loss: 0.5675, Avg D_B Loss: 0.5328, Avg G Loss: 4.3625
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.86MB
# Epoch 123, Avg D_A Loss: 0.5708, Avg D_B Loss: 0.5171, Avg G Loss: 4.4068
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 115.11MB
# Epoch 124, Avg D_A Loss: 0.5781, Avg D_B Loss: 0.5178, Avg G Loss: 4.3880
# Batch 0, Data time: 0.00s, Query time: 0.08s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 125, Avg D_A Loss: 0.5736, Avg D_B Loss: 0.5359, Avg G Loss: 4.3226
# Batch 0, Data time: 0.00s, Query time: 0.33s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 126, Avg D_A Loss: 0.5704, Avg D_B Loss: 0.5227, Avg G Loss: 4.3742
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 115.24MB
# Epoch 127, Avg D_A Loss: 0.5721, Avg D_B Loss: 0.5133, Avg G Loss: 4.4933
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 112.36MB
# Epoch 128, Avg D_A Loss: 0.5715, Avg D_B Loss: 0.5332, Avg G Loss: 4.4951
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 129, Avg D_A Loss: 0.5714, Avg D_B Loss: 0.5195, Avg G Loss: 4.4484
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 130, Avg D_A Loss: 0.5732, Avg D_B Loss: 0.5258, Avg G Loss: 4.5971
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 131, Avg D_A Loss: 0.5665, Avg D_B Loss: 0.5124, Avg G Loss: 4.5567
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 132, Avg D_A Loss: 0.5741, Avg D_B Loss: 0.5295, Avg G Loss: 4.5387
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.68MB
# Epoch 133, Avg D_A Loss: 0.5645, Avg D_B Loss: 0.5212, Avg G Loss: 4.5178
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.43MB
# Epoch 134, Avg D_A Loss: 0.5582, Avg D_B Loss: 0.5189, Avg G Loss: 4.4456
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.49MB
# Epoch 135, Avg D_A Loss: 0.5790, Avg D_B Loss: 0.5059, Avg G Loss: 4.4393
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 136, Avg D_A Loss: 0.5625, Avg D_B Loss: 0.5209, Avg G Loss: 4.5186
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 113.49MB
# Epoch 137, Avg D_A Loss: 0.5713, Avg D_B Loss: 0.4990, Avg G Loss: 4.4846
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 113.11MB
# Epoch 138, Avg D_A Loss: 0.5591, Avg D_B Loss: 0.5142, Avg G Loss: 4.4550
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 139, Avg D_A Loss: 0.5823, Avg D_B Loss: 0.4977, Avg G Loss: 4.4928
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.55MB
# Epoch 140, Avg D_A Loss: 0.5672, Avg D_B Loss: 0.4929, Avg G Loss: 4.4937
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 141, Avg D_A Loss: 0.5725, Avg D_B Loss: 0.5046, Avg G Loss: 4.5600
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 142, Avg D_A Loss: 0.5577, Avg D_B Loss: 0.4915, Avg G Loss: 4.4612
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 143, Avg D_A Loss: 0.5651, Avg D_B Loss: 0.5049, Avg G Loss: 4.5123
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 144, Avg D_A Loss: 0.5531, Avg D_B Loss: 0.5126, Avg G Loss: 4.5060
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 145, Avg D_A Loss: 0.5494, Avg D_B Loss: 0.5068, Avg G Loss: 4.4815
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 146, Avg D_A Loss: 0.5491, Avg D_B Loss: 0.5031, Avg G Loss: 4.5128
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.68MB
# Epoch 147, Avg D_A Loss: 0.5690, Avg D_B Loss: 0.5096, Avg G Loss: 4.5353
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 148, Avg D_A Loss: 0.5667, Avg D_B Loss: 0.4897, Avg G Loss: 4.6881
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 149, Avg D_A Loss: 0.5739, Avg D_B Loss: 0.5062, Avg G Loss: 4.5943
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 150, Avg D_A Loss: 0.5720, Avg D_B Loss: 0.5154, Avg G Loss: 4.5973
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 151, Avg D_A Loss: 0.5576, Avg D_B Loss: 0.4995, Avg G Loss: 4.5754
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.49MB
# Epoch 152, Avg D_A Loss: 0.5741, Avg D_B Loss: 0.5019, Avg G Loss: 4.3756
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 114.05MB
# Epoch 153, Avg D_A Loss: 0.5622, Avg D_B Loss: 0.4888, Avg G Loss: 4.4689
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 154, Avg D_A Loss: 0.5664, Avg D_B Loss: 0.4797, Avg G Loss: 4.5041
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 155, Avg D_A Loss: 0.5634, Avg D_B Loss: 0.4932, Avg G Loss: 4.4575
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 156, Avg D_A Loss: 0.5645, Avg D_B Loss: 0.4837, Avg G Loss: 4.4689
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 157, Avg D_A Loss: 0.5689, Avg D_B Loss: 0.4939, Avg G Loss: 4.4908
# Batch 0, Data time: 0.00s, Query time: 0.08s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 158, Avg D_A Loss: 0.5663, Avg D_B Loss: 0.5012, Avg G Loss: 4.5669
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 159, Avg D_A Loss: 0.5625, Avg D_B Loss: 0.4834, Avg G Loss: 4.4940
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 160, Avg D_A Loss: 0.5695, Avg D_B Loss: 0.4895, Avg G Loss: 4.5471
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 109.68MB
# Epoch 161, Avg D_A Loss: 0.5650, Avg D_B Loss: 0.4920, Avg G Loss: 4.5469
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 162, Avg D_A Loss: 0.5611, Avg D_B Loss: 0.5062, Avg G Loss: 4.5021
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 163, Avg D_A Loss: 0.5703, Avg D_B Loss: 0.4857, Avg G Loss: 4.4882
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.99MB
# Epoch 164, Avg D_A Loss: 0.5791, Avg D_B Loss: 0.4975, Avg G Loss: 4.6315
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.55MB
# Epoch 165, Avg D_A Loss: 0.5603, Avg D_B Loss: 0.4863, Avg G Loss: 4.5908
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.43MB
# Epoch 166, Avg D_A Loss: 0.5713, Avg D_B Loss: 0.5039, Avg G Loss: 4.5006
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 167, Avg D_A Loss: 0.5677, Avg D_B Loss: 0.4970, Avg G Loss: 4.6045
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.36MB
# Epoch 168, Avg D_A Loss: 0.5672, Avg D_B Loss: 0.4908, Avg G Loss: 4.5316
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 169, Avg D_A Loss: 0.5756, Avg D_B Loss: 0.4889, Avg G Loss: 4.4683
# Batch 0, Data time: 0.00s, Query time: 0.03s, Model time: 0.26s, VRAM: 111.36MB
# Epoch 170, Avg D_A Loss: 0.5688, Avg D_B Loss: 0.4787, Avg G Loss: 4.4995
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.36MB
# Epoch 171, Avg D_A Loss: 0.5753, Avg D_B Loss: 0.4814, Avg G Loss: 4.5286
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 172, Avg D_A Loss: 0.5671, Avg D_B Loss: 0.4772, Avg G Loss: 4.5379
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.36MB
# Epoch 173, Avg D_A Loss: 0.5647, Avg D_B Loss: 0.4749, Avg G Loss: 4.5585
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.43MB
# Epoch 174, Avg D_A Loss: 0.5687, Avg D_B Loss: 0.4780, Avg G Loss: 4.5752
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 175, Avg D_A Loss: 0.5660, Avg D_B Loss: 0.4866, Avg G Loss: 4.5972
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.05MB
# Epoch 176, Avg D_A Loss: 0.5713, Avg D_B Loss: 0.4922, Avg G Loss: 4.5917
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 177, Avg D_A Loss: 0.5588, Avg D_B Loss: 0.4866, Avg G Loss: 4.5146
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 178, Avg D_A Loss: 0.5534, Avg D_B Loss: 0.4832, Avg G Loss: 4.5319
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 113.05MB
# Epoch 179, Avg D_A Loss: 0.5619, Avg D_B Loss: 0.4701, Avg G Loss: 4.5066
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.18MB
# Epoch 180, Avg D_A Loss: 0.5508, Avg D_B Loss: 0.4742, Avg G Loss: 4.5297
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.86MB
# Epoch 181, Avg D_A Loss: 0.5666, Avg D_B Loss: 0.4885, Avg G Loss: 4.5343
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 115.11MB
# Epoch 182, Avg D_A Loss: 0.5630, Avg D_B Loss: 0.4675, Avg G Loss: 4.5261
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 183, Avg D_A Loss: 0.5696, Avg D_B Loss: 0.4788, Avg G Loss: 4.5187
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 184, Avg D_A Loss: 0.5608, Avg D_B Loss: 0.4839, Avg G Loss: 4.5291
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 115.24MB
# Epoch 185, Avg D_A Loss: 0.5604, Avg D_B Loss: 0.4892, Avg G Loss: 4.5592
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.36MB
# Epoch 186, Avg D_A Loss: 0.5671, Avg D_B Loss: 0.5011, Avg G Loss: 4.7466
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 187, Avg D_A Loss: 0.5709, Avg D_B Loss: 0.4795, Avg G Loss: 4.6676
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 188, Avg D_A Loss: 0.5628, Avg D_B Loss: 0.4659, Avg G Loss: 4.6160
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 189, Avg D_A Loss: 0.5526, Avg D_B Loss: 0.4764, Avg G Loss: 4.5370
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 190, Avg D_A Loss: 0.5627, Avg D_B Loss: 0.4687, Avg G Loss: 4.4751
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.68MB
# Epoch 191, Avg D_A Loss: 0.5508, Avg D_B Loss: 0.4785, Avg G Loss: 4.4381
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.43MB
# Epoch 192, Avg D_A Loss: 0.5516, Avg D_B Loss: 0.4810, Avg G Loss: 4.4729
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.49MB
# Epoch 193, Avg D_A Loss: 0.5500, Avg D_B Loss: 0.4806, Avg G Loss: 4.5798
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 194, Avg D_A Loss: 0.5538, Avg D_B Loss: 0.4685, Avg G Loss: 4.5479
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 113.49MB
# Epoch 195, Avg D_A Loss: 0.5630, Avg D_B Loss: 0.4831, Avg G Loss: 4.5626
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 113.11MB
# Epoch 196, Avg D_A Loss: 0.5622, Avg D_B Loss: 0.4837, Avg G Loss: 4.5372
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 197, Avg D_A Loss: 0.5567, Avg D_B Loss: 0.4776, Avg G Loss: 4.5663
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 111.55MB
# Epoch 198, Avg D_A Loss: 0.5628, Avg D_B Loss: 0.4692, Avg G Loss: 4.5996
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 199, Avg D_A Loss: 0.5514, Avg D_B Loss: 0.4837, Avg G Loss: 4.5718
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 200, Avg D_A Loss: 0.5553, Avg D_B Loss: 0.4810, Avg G Loss: 4.5934
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 201, Avg D_A Loss: 0.5523, Avg D_B Loss: 0.4766, Avg G Loss: 4.6196
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 202, Avg D_A Loss: 0.5680, Avg D_B Loss: 0.4779, Avg G Loss: 4.6249
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 203, Avg D_A Loss: 0.5507, Avg D_B Loss: 0.4836, Avg G Loss: 4.6739
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 204, Avg D_A Loss: 0.5583, Avg D_B Loss: 0.4746, Avg G Loss: 4.5518
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.68MB
# Epoch 205, Avg D_A Loss: 0.5637, Avg D_B Loss: 0.4765, Avg G Loss: 4.5960
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 206, Avg D_A Loss: 0.5537, Avg D_B Loss: 0.4711, Avg G Loss: 4.5762
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 207, Avg D_A Loss: 0.5585, Avg D_B Loss: 0.4841, Avg G Loss: 4.5387
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 208, Avg D_A Loss: 0.5485, Avg D_B Loss: 0.4700, Avg G Loss: 4.5332
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 209, Avg D_A Loss: 0.5654, Avg D_B Loss: 0.4803, Avg G Loss: 4.5388
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.49MB
# Epoch 210, Avg D_A Loss: 0.5475, Avg D_B Loss: 0.4710, Avg G Loss: 4.5944
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 114.05MB
# Epoch 211, Avg D_A Loss: 0.5584, Avg D_B Loss: 0.4766, Avg G Loss: 4.5766
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 212, Avg D_A Loss: 0.5523, Avg D_B Loss: 0.4704, Avg G Loss: 4.5670
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 213, Avg D_A Loss: 0.5586, Avg D_B Loss: 0.4746, Avg G Loss: 4.5813
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 214, Avg D_A Loss: 0.5471, Avg D_B Loss: 0.4707, Avg G Loss: 4.6258
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 215, Avg D_A Loss: 0.5522, Avg D_B Loss: 0.4594, Avg G Loss: 4.5626
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 216, Avg D_A Loss: 0.5512, Avg D_B Loss: 0.4657, Avg G Loss: 4.5920
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 217, Avg D_A Loss: 0.5609, Avg D_B Loss: 0.4598, Avg G Loss: 4.5480
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 218, Avg D_A Loss: 0.5571, Avg D_B Loss: 0.4639, Avg G Loss: 4.5631
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 109.68MB
# Epoch 219, Avg D_A Loss: 0.5523, Avg D_B Loss: 0.4655, Avg G Loss: 4.5797
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 220, Avg D_A Loss: 0.5528, Avg D_B Loss: 0.4719, Avg G Loss: 4.5597
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 221, Avg D_A Loss: 0.5566, Avg D_B Loss: 0.4768, Avg G Loss: 4.5870
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.99MB
# Epoch 222, Avg D_A Loss: 0.5582, Avg D_B Loss: 0.4793, Avg G Loss: 4.5732
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.55MB
# Epoch 223, Avg D_A Loss: 0.5531, Avg D_B Loss: 0.4676, Avg G Loss: 4.6006
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.43MB
# Epoch 224, Avg D_A Loss: 0.5576, Avg D_B Loss: 0.4575, Avg G Loss: 4.5524
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 225, Avg D_A Loss: 0.5519, Avg D_B Loss: 0.4433, Avg G Loss: 4.5979
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.36MB
# Epoch 226, Avg D_A Loss: 0.5540, Avg D_B Loss: 0.4585, Avg G Loss: 4.6030
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 227, Avg D_A Loss: 0.5469, Avg D_B Loss: 0.4723, Avg G Loss: 4.5549
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.36MB
# Epoch 228, Avg D_A Loss: 0.5550, Avg D_B Loss: 0.4596, Avg G Loss: 4.5515
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.36MB
# Epoch 229, Avg D_A Loss: 0.5583, Avg D_B Loss: 0.4445, Avg G Loss: 4.6304
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 230, Avg D_A Loss: 0.5451, Avg D_B Loss: 0.4591, Avg G Loss: 4.6286
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.36MB
# Epoch 231, Avg D_A Loss: 0.5560, Avg D_B Loss: 0.4478, Avg G Loss: 4.6238
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.43MB
# Epoch 232, Avg D_A Loss: 0.5622, Avg D_B Loss: 0.4663, Avg G Loss: 4.6866
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 233, Avg D_A Loss: 0.5580, Avg D_B Loss: 0.4644, Avg G Loss: 4.6122
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 112.05MB
# Epoch 234, Avg D_A Loss: 0.5465, Avg D_B Loss: 0.4695, Avg G Loss: 4.5787
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 235, Avg D_A Loss: 0.5558, Avg D_B Loss: 0.4531, Avg G Loss: 4.6070
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 236, Avg D_A Loss: 0.5566, Avg D_B Loss: 0.4576, Avg G Loss: 4.5713
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 113.05MB
# Epoch 237, Avg D_A Loss: 0.5577, Avg D_B Loss: 0.4624, Avg G Loss: 4.6127
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 112.18MB
# Epoch 238, Avg D_A Loss: 0.5564, Avg D_B Loss: 0.4494, Avg G Loss: 4.5560
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.86MB
# Epoch 239, Avg D_A Loss: 0.5657, Avg D_B Loss: 0.4509, Avg G Loss: 4.5231
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 115.11MB
# Epoch 240, Avg D_A Loss: 0.5515, Avg D_B Loss: 0.4493, Avg G Loss: 4.5219
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 241, Avg D_A Loss: 0.5541, Avg D_B Loss: 0.4442, Avg G Loss: 4.5738
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 242, Avg D_A Loss: 0.5524, Avg D_B Loss: 0.4565, Avg G Loss: 4.5271
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 115.24MB
# Epoch 243, Avg D_A Loss: 0.5634, Avg D_B Loss: 0.4411, Avg G Loss: 4.5581
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.36MB
# Epoch 244, Avg D_A Loss: 0.5428, Avg D_B Loss: 0.4519, Avg G Loss: 4.5917
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 245, Avg D_A Loss: 0.5575, Avg D_B Loss: 0.4613, Avg G Loss: 4.5719
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 246, Avg D_A Loss: 0.5518, Avg D_B Loss: 0.4569, Avg G Loss: 4.6007
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 247, Avg D_A Loss: 0.5436, Avg D_B Loss: 0.4576, Avg G Loss: 4.6032
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 248, Avg D_A Loss: 0.5624, Avg D_B Loss: 0.4442, Avg G Loss: 4.6934
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.68MB
# Epoch 249, Avg D_A Loss: 0.5540, Avg D_B Loss: 0.4554, Avg G Loss: 4.6682
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.43MB
# Epoch 250, Avg D_A Loss: 0.5519, Avg D_B Loss: 0.4453, Avg G Loss: 4.6808
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.49MB
# Epoch 251, Avg D_A Loss: 0.5626, Avg D_B Loss: 0.4552, Avg G Loss: 4.6626
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 252, Avg D_A Loss: 0.5544, Avg D_B Loss: 0.4515, Avg G Loss: 4.6841
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 113.49MB
# Epoch 253, Avg D_A Loss: 0.5566, Avg D_B Loss: 0.4444, Avg G Loss: 4.6826
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 113.11MB
# Epoch 254, Avg D_A Loss: 0.5543, Avg D_B Loss: 0.4379, Avg G Loss: 4.6136
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 255, Avg D_A Loss: 0.5512, Avg D_B Loss: 0.4441, Avg G Loss: 4.6719
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.55MB
# Epoch 256, Avg D_A Loss: 0.5491, Avg D_B Loss: 0.4510, Avg G Loss: 4.6870
# Batch 0, Data time: 0.00s, Query time: 0.03s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 257, Avg D_A Loss: 0.5449, Avg D_B Loss: 0.4552, Avg G Loss: 4.7071
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 258, Avg D_A Loss: 0.5580, Avg D_B Loss: 0.4425, Avg G Loss: 4.6631
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 259, Avg D_A Loss: 0.5685, Avg D_B Loss: 0.4415, Avg G Loss: 4.6210
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 260, Avg D_A Loss: 0.5505, Avg D_B Loss: 0.4392, Avg G Loss: 4.6261
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 261, Avg D_A Loss: 0.5591, Avg D_B Loss: 0.4585, Avg G Loss: 4.6800
# Batch 0, Data time: 0.00s, Query time: 0.03s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 262, Avg D_A Loss: 0.5526, Avg D_B Loss: 0.4380, Avg G Loss: 4.6369
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.68MB
# Epoch 263, Avg D_A Loss: 0.5411, Avg D_B Loss: 0.4383, Avg G Loss: 4.6033
# Batch 0, Data time: 0.00s, Query time: 0.09s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 264, Avg D_A Loss: 0.5474, Avg D_B Loss: 0.4378, Avg G Loss: 4.5384
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 265, Avg D_A Loss: 0.5488, Avg D_B Loss: 0.4314, Avg G Loss: 4.4868
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 266, Avg D_A Loss: 0.5587, Avg D_B Loss: 0.4367, Avg G Loss: 4.4986
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 267, Avg D_A Loss: 0.5541, Avg D_B Loss: 0.4342, Avg G Loss: 4.6268
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.49MB
# Epoch 268, Avg D_A Loss: 0.5553, Avg D_B Loss: 0.4321, Avg G Loss: 4.6268
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 114.05MB
# Epoch 269, Avg D_A Loss: 0.5598, Avg D_B Loss: 0.4344, Avg G Loss: 4.5914
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 270, Avg D_A Loss: 0.5499, Avg D_B Loss: 0.4517, Avg G Loss: 4.5641
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 271, Avg D_A Loss: 0.5452, Avg D_B Loss: 0.4341, Avg G Loss: 4.6062
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 272, Avg D_A Loss: 0.5518, Avg D_B Loss: 0.4345, Avg G Loss: 4.5490
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 273, Avg D_A Loss: 0.5535, Avg D_B Loss: 0.4380, Avg G Loss: 4.6448
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 274, Avg D_A Loss: 0.5635, Avg D_B Loss: 0.4488, Avg G Loss: 4.5996
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 275, Avg D_A Loss: 0.5498, Avg D_B Loss: 0.4510, Avg G Loss: 4.6488
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 276, Avg D_A Loss: 0.5534, Avg D_B Loss: 0.4378, Avg G Loss: 4.6375
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 109.68MB
# Epoch 277, Avg D_A Loss: 0.5455, Avg D_B Loss: 0.4206, Avg G Loss: 4.6151
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 278, Avg D_A Loss: 0.5528, Avg D_B Loss: 0.4363, Avg G Loss: 4.6519
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 279, Avg D_A Loss: 0.5527, Avg D_B Loss: 0.4224, Avg G Loss: 4.6544
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.99MB
# Epoch 280, Avg D_A Loss: 0.5380, Avg D_B Loss: 0.4271, Avg G Loss: 4.5795
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.55MB
# Epoch 281, Avg D_A Loss: 0.5592, Avg D_B Loss: 0.4362, Avg G Loss: 4.5949
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.43MB
# Epoch 282, Avg D_A Loss: 0.5532, Avg D_B Loss: 0.4415, Avg G Loss: 4.6536
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 283, Avg D_A Loss: 0.5585, Avg D_B Loss: 0.4293, Avg G Loss: 4.7399
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.36MB
# Epoch 284, Avg D_A Loss: 0.5494, Avg D_B Loss: 0.4387, Avg G Loss: 4.7081
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 285, Avg D_A Loss: 0.5478, Avg D_B Loss: 0.4229, Avg G Loss: 4.6965
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.36MB
# Epoch 286, Avg D_A Loss: 0.5584, Avg D_B Loss: 0.4269, Avg G Loss: 4.6811
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.36MB
# Epoch 287, Avg D_A Loss: 0.5429, Avg D_B Loss: 0.4438, Avg G Loss: 4.6138
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 288, Avg D_A Loss: 0.5567, Avg D_B Loss: 0.4306, Avg G Loss: 4.7101
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.36MB
# Epoch 289, Avg D_A Loss: 0.5391, Avg D_B Loss: 0.4356, Avg G Loss: 4.7061
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.43MB
# Epoch 290, Avg D_A Loss: 0.5457, Avg D_B Loss: 0.4406, Avg G Loss: 4.6581
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 291, Avg D_A Loss: 0.5569, Avg D_B Loss: 0.4242, Avg G Loss: 4.6439
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.05MB
# Epoch 292, Avg D_A Loss: 0.5499, Avg D_B Loss: 0.4365, Avg G Loss: 4.6170
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 293, Avg D_A Loss: 0.5539, Avg D_B Loss: 0.4291, Avg G Loss: 4.6690
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 294, Avg D_A Loss: 0.5573, Avg D_B Loss: 0.4253, Avg G Loss: 4.7175
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 113.05MB
# Epoch 295, Avg D_A Loss: 0.5691, Avg D_B Loss: 0.4400, Avg G Loss: 4.6133
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.18MB
# Epoch 296, Avg D_A Loss: 0.5660, Avg D_B Loss: 0.4331, Avg G Loss: 4.6788
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.86MB
# Epoch 297, Avg D_A Loss: 0.5504, Avg D_B Loss: 0.4382, Avg G Loss: 4.6330
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 115.11MB
# Epoch 298, Avg D_A Loss: 0.5513, Avg D_B Loss: 0.4453, Avg G Loss: 4.6918
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 299, Avg D_A Loss: 0.5483, Avg D_B Loss: 0.4266, Avg G Loss: 4.6628
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 300, Avg D_A Loss: 0.5551, Avg D_B Loss: 0.4286, Avg G Loss: 4.6290
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 115.24MB
# Epoch 301, Avg D_A Loss: 0.5558, Avg D_B Loss: 0.4295, Avg G Loss: 4.6556
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.36MB
# Epoch 302, Avg D_A Loss: 0.5579, Avg D_B Loss: 0.4166, Avg G Loss: 4.6670
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 303, Avg D_A Loss: 0.5604, Avg D_B Loss: 0.4097, Avg G Loss: 4.6657
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 304, Avg D_A Loss: 0.5497, Avg D_B Loss: 0.4236, Avg G Loss: 4.7344
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 305, Avg D_A Loss: 0.5641, Avg D_B Loss: 0.4300, Avg G Loss: 4.6851
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 306, Avg D_A Loss: 0.5627, Avg D_B Loss: 0.4299, Avg G Loss: 4.6853
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.68MB
# Epoch 307, Avg D_A Loss: 0.5463, Avg D_B Loss: 0.4257, Avg G Loss: 4.6608
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.43MB
# Epoch 308, Avg D_A Loss: 0.5458, Avg D_B Loss: 0.4312, Avg G Loss: 4.7380
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.49MB
# Epoch 309, Avg D_A Loss: 0.5606, Avg D_B Loss: 0.4186, Avg G Loss: 4.7021
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 310, Avg D_A Loss: 0.5571, Avg D_B Loss: 0.4244, Avg G Loss: 4.7274
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 113.49MB
# Epoch 311, Avg D_A Loss: 0.5565, Avg D_B Loss: 0.4224, Avg G Loss: 4.7256
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 113.11MB
# Epoch 312, Avg D_A Loss: 0.5598, Avg D_B Loss: 0.4146, Avg G Loss: 4.7233
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 313, Avg D_A Loss: 0.5549, Avg D_B Loss: 0.4342, Avg G Loss: 4.6923
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.55MB
# Epoch 314, Avg D_A Loss: 0.5502, Avg D_B Loss: 0.4031, Avg G Loss: 4.6589
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 315, Avg D_A Loss: 0.5480, Avg D_B Loss: 0.4424, Avg G Loss: 4.5858
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 316, Avg D_A Loss: 0.5426, Avg D_B Loss: 0.4156, Avg G Loss: 4.6914
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 317, Avg D_A Loss: 0.5479, Avg D_B Loss: 0.4175, Avg G Loss: 4.7043
# Batch 0, Data time: 0.00s, Query time: 0.03s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 318, Avg D_A Loss: 0.5556, Avg D_B Loss: 0.4213, Avg G Loss: 4.7425
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 319, Avg D_A Loss: 0.5605, Avg D_B Loss: 0.4134, Avg G Loss: 4.7569
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 320, Avg D_A Loss: 0.5569, Avg D_B Loss: 0.4171, Avg G Loss: 4.7447
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.68MB
# Epoch 321, Avg D_A Loss: 0.5519, Avg D_B Loss: 0.4168, Avg G Loss: 4.6725
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 322, Avg D_A Loss: 0.5511, Avg D_B Loss: 0.4203, Avg G Loss: 4.6095
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 323, Avg D_A Loss: 0.5426, Avg D_B Loss: 0.4144, Avg G Loss: 4.7297
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 324, Avg D_A Loss: 0.5571, Avg D_B Loss: 0.4136, Avg G Loss: 4.6744
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 325, Avg D_A Loss: 0.5511, Avg D_B Loss: 0.4222, Avg G Loss: 4.7927
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.49MB
# Epoch 326, Avg D_A Loss: 0.5394, Avg D_B Loss: 0.4310, Avg G Loss: 4.7339
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 114.05MB
# Epoch 327, Avg D_A Loss: 0.5442, Avg D_B Loss: 0.4112, Avg G Loss: 4.7164
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 328, Avg D_A Loss: 0.5464, Avg D_B Loss: 0.4125, Avg G Loss: 4.7332
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 329, Avg D_A Loss: 0.5464, Avg D_B Loss: 0.4072, Avg G Loss: 4.6872
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 330, Avg D_A Loss: 0.5500, Avg D_B Loss: 0.4305, Avg G Loss: 4.6936
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 331, Avg D_A Loss: 0.5400, Avg D_B Loss: 0.4121, Avg G Loss: 4.6871
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 332, Avg D_A Loss: 0.5549, Avg D_B Loss: 0.4057, Avg G Loss: 4.7112
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 333, Avg D_A Loss: 0.5535, Avg D_B Loss: 0.4102, Avg G Loss: 4.6652
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 334, Avg D_A Loss: 0.5294, Avg D_B Loss: 0.4210, Avg G Loss: 4.6652
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 109.68MB
# Epoch 335, Avg D_A Loss: 0.5531, Avg D_B Loss: 0.4148, Avg G Loss: 4.6974
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 336, Avg D_A Loss: 0.5479, Avg D_B Loss: 0.4249, Avg G Loss: 4.7842
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 337, Avg D_A Loss: 0.5338, Avg D_B Loss: 0.4149, Avg G Loss: 4.7413
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.99MB
# Epoch 338, Avg D_A Loss: 0.5447, Avg D_B Loss: 0.4111, Avg G Loss: 4.7185
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.55MB
# Epoch 339, Avg D_A Loss: 0.5425, Avg D_B Loss: 0.4025, Avg G Loss: 4.7085
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.43MB
# Epoch 340, Avg D_A Loss: 0.5480, Avg D_B Loss: 0.4063, Avg G Loss: 4.6992
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 341, Avg D_A Loss: 0.5393, Avg D_B Loss: 0.4047, Avg G Loss: 4.7466
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.36MB
# Epoch 342, Avg D_A Loss: 0.5479, Avg D_B Loss: 0.4015, Avg G Loss: 4.7661
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 343, Avg D_A Loss: 0.5553, Avg D_B Loss: 0.3961, Avg G Loss: 4.7504
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.36MB
# Epoch 344, Avg D_A Loss: 0.5563, Avg D_B Loss: 0.4022, Avg G Loss: 4.7246
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.36MB
# Epoch 345, Avg D_A Loss: 0.5414, Avg D_B Loss: 0.4280, Avg G Loss: 4.7506
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 346, Avg D_A Loss: 0.5456, Avg D_B Loss: 0.4103, Avg G Loss: 4.7111
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 111.36MB
# Epoch 347, Avg D_A Loss: 0.5523, Avg D_B Loss: 0.4231, Avg G Loss: 4.7897
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.43MB
# Epoch 348, Avg D_A Loss: 0.5572, Avg D_B Loss: 0.4225, Avg G Loss: 4.7377
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 349, Avg D_A Loss: 0.5376, Avg D_B Loss: 0.3924, Avg G Loss: 4.7510
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.05MB
# Epoch 350, Avg D_A Loss: 0.5374, Avg D_B Loss: 0.4263, Avg G Loss: 4.7853
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 351, Avg D_A Loss: 0.5511, Avg D_B Loss: 0.4093, Avg G Loss: 4.7157
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 352, Avg D_A Loss: 0.5371, Avg D_B Loss: 0.4054, Avg G Loss: 4.6830
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 113.05MB
# Epoch 353, Avg D_A Loss: 0.5426, Avg D_B Loss: 0.3923, Avg G Loss: 4.7633
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.18MB
# Epoch 354, Avg D_A Loss: 0.5406, Avg D_B Loss: 0.4089, Avg G Loss: 4.6700
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.86MB
# Epoch 355, Avg D_A Loss: 0.5376, Avg D_B Loss: 0.4048, Avg G Loss: 4.7262
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 115.11MB
# Epoch 356, Avg D_A Loss: 0.5461, Avg D_B Loss: 0.3993, Avg G Loss: 4.6851
# Batch 0, Data time: 0.00s, Query time: 0.08s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 357, Avg D_A Loss: 0.5337, Avg D_B Loss: 0.3980, Avg G Loss: 4.7231
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 358, Avg D_A Loss: 0.5447, Avg D_B Loss: 0.3871, Avg G Loss: 4.7862
# Batch 0, Data time: 0.00s, Query time: 0.09s, Model time: 0.26s, VRAM: 115.24MB
# Epoch 359, Avg D_A Loss: 0.5456, Avg D_B Loss: 0.4137, Avg G Loss: 4.7654
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.36MB
# Epoch 360, Avg D_A Loss: 0.5521, Avg D_B Loss: 0.3988, Avg G Loss: 4.7040
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 361, Avg D_A Loss: 0.5448, Avg D_B Loss: 0.3899, Avg G Loss: 4.8021
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 362, Avg D_A Loss: 0.5343, Avg D_B Loss: 0.4246, Avg G Loss: 4.7493
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 363, Avg D_A Loss: 0.5399, Avg D_B Loss: 0.4072, Avg G Loss: 4.8393
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 364, Avg D_A Loss: 0.5387, Avg D_B Loss: 0.3896, Avg G Loss: 4.8289
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.68MB
# Epoch 365, Avg D_A Loss: 0.5324, Avg D_B Loss: 0.4097, Avg G Loss: 4.7376
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 110.43MB
# Epoch 366, Avg D_A Loss: 0.5344, Avg D_B Loss: 0.3974, Avg G Loss: 4.7362
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.49MB
# Epoch 367, Avg D_A Loss: 0.5279, Avg D_B Loss: 0.4037, Avg G Loss: 4.8441
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.18MB
# Epoch 368, Avg D_A Loss: 0.5362, Avg D_B Loss: 0.3835, Avg G Loss: 4.8613
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 113.49MB
# Epoch 369, Avg D_A Loss: 0.5358, Avg D_B Loss: 0.4037, Avg G Loss: 4.8440
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 113.11MB
# Epoch 370, Avg D_A Loss: 0.5479, Avg D_B Loss: 0.3960, Avg G Loss: 4.7933
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 371, Avg D_A Loss: 0.5385, Avg D_B Loss: 0.3908, Avg G Loss: 4.7929
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 111.55MB
# Epoch 372, Avg D_A Loss: 0.5422, Avg D_B Loss: 0.4047, Avg G Loss: 4.7343
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 373, Avg D_A Loss: 0.5405, Avg D_B Loss: 0.4041, Avg G Loss: 4.8075
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 374, Avg D_A Loss: 0.5362, Avg D_B Loss: 0.3962, Avg G Loss: 4.8345
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 375, Avg D_A Loss: 0.5405, Avg D_B Loss: 0.3840, Avg G Loss: 4.8323
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 111.61MB
# Epoch 376, Avg D_A Loss: 0.5373, Avg D_B Loss: 0.3887, Avg G Loss: 4.8151
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.80MB
# Epoch 377, Avg D_A Loss: 0.5338, Avg D_B Loss: 0.3947, Avg G Loss: 4.8608
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 378, Avg D_A Loss: 0.5357, Avg D_B Loss: 0.3830, Avg G Loss: 4.8425
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.68MB
# Epoch 379, Avg D_A Loss: 0.5266, Avg D_B Loss: 0.3809, Avg G Loss: 4.8202
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 380, Avg D_A Loss: 0.5270, Avg D_B Loss: 0.3972, Avg G Loss: 4.7911
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 381, Avg D_A Loss: 0.5485, Avg D_B Loss: 0.3926, Avg G Loss: 4.8227
# Batch 0, Data time: 0.00s, Query time: 0.09s, Model time: 0.27s, VRAM: 111.11MB
# Epoch 382, Avg D_A Loss: 0.5443, Avg D_B Loss: 0.4133, Avg G Loss: 4.7620
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 110.93MB
# Epoch 383, Avg D_A Loss: 0.5451, Avg D_B Loss: 0.3998, Avg G Loss: 4.8497
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.49MB
# Epoch 384, Avg D_A Loss: 0.5409, Avg D_B Loss: 0.3972, Avg G Loss: 4.8128
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 114.05MB
# Epoch 385, Avg D_A Loss: 0.5423, Avg D_B Loss: 0.4215, Avg G Loss: 4.8305
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 386, Avg D_A Loss: 0.5459, Avg D_B Loss: 0.4091, Avg G Loss: 4.8822
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 387, Avg D_A Loss: 0.5369, Avg D_B Loss: 0.3848, Avg G Loss: 4.8203
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 388, Avg D_A Loss: 0.5387, Avg D_B Loss: 0.3777, Avg G Loss: 4.7941
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.11MB
# Epoch 389, Avg D_A Loss: 0.5451, Avg D_B Loss: 0.3925, Avg G Loss: 4.8654
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 390, Avg D_A Loss: 0.5428, Avg D_B Loss: 0.3889, Avg G Loss: 4.8898
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 110.11MB
# Epoch 391, Avg D_A Loss: 0.5366, Avg D_B Loss: 0.3927, Avg G Loss: 4.7839
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 111.74MB
# Epoch 392, Avg D_A Loss: 0.5383, Avg D_B Loss: 0.3818, Avg G Loss: 4.8907
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 109.68MB
# Epoch 393, Avg D_A Loss: 0.5423, Avg D_B Loss: 0.3885, Avg G Loss: 4.8732
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 394, Avg D_A Loss: 0.5376, Avg D_B Loss: 0.4044, Avg G Loss: 4.9232
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.61MB
# Epoch 395, Avg D_A Loss: 0.5312, Avg D_B Loss: 0.3803, Avg G Loss: 4.8451
# Batch 0, Data time: 0.00s, Query time: 0.04s, Model time: 0.26s, VRAM: 112.99MB
# Epoch 396, Avg D_A Loss: 0.5296, Avg D_B Loss: 0.3927, Avg G Loss: 4.7837
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 110.55MB
# Epoch 397, Avg D_A Loss: 0.5234, Avg D_B Loss: 0.3856, Avg G Loss: 4.8814
# Batch 0, Data time: 0.00s, Query time: 0.05s, Model time: 0.26s, VRAM: 112.43MB
# Epoch 398, Avg D_A Loss: 0.5260, Avg D_B Loss: 0.3720, Avg G Loss: 4.7993
# Batch 0, Data time: 0.00s, Query time: 0.06s, Model time: 0.26s, VRAM: 112.11MB
# Epoch 399, Avg D_A Loss: 0.5378, Avg D_B Loss: 0.3848, Avg G Loss: 4.8198
# Batch 0, Data time: 0.00s, Query time: 0.07s, Model time: 0.26s, VRAM: 110.36MB
# Epoch 400, Avg D_A Loss: 0.5333, Avg D_B Loss: 0.3934, Avg G Loss: 4.9004

# %%
# Vẽ kết quả mẫu
real_A, condition_A = dataset[0]
real_A = real_A.unsqueeze(0).to(device)
condition_A = condition_A.unsqueeze(0).to(device)
target_age = torch.tensor([50.0 / max_age], dtype=torch.float32, device=device)
target_gender = torch.tensor([1.0], dtype=torch.float32, device=device)
condition_A_to_B = torch.tensor([condition_A[0, 0], condition_A[0, 1], target_age, target_gender], dtype=torch.float32, device=device).unsqueeze(0)
with torch.no_grad():
    fake_B = G_A_to_B(real_A, condition_A_to_B)
fake_B = fake_B.cpu().numpy()[0]  # Shape: (3, 64, 64)

plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title("Generated Axial")
plt.imshow(fake_B[0], cmap='gray')
plt.axis('off')
plt.subplot(1, 3, 2)
plt.title("Generated Coronal")
plt.imshow(fake_B[1], cmap='gray')
plt.axis('off')
plt.subplot(1, 3, 3)
plt.title("Generated Sagittal")
plt.imshow(fake_B[2], cmap='gray')
plt.axis('off')
plt.tight_layout()
plt.savefig('/kaggle/working/generated_slices.png')
plt.close()

# %%
# Vẽ kết quả mẫu
real_A, condition_A = dataset[0]
real_A = real_A.unsqueeze(0).to(device)
condition_A = condition_A.unsqueeze(0).to(device)
target_age = torch.tensor([50.0 / max_age], dtype=torch.float32, device=device)
target_gender = torch.tensor([1.0], dtype=torch.float32, device=device)
condition_A_to_B = torch.tensor([condition_A[0, 0], condition_A[0, 1], target_age, target_gender], dtype=torch.float32, device=device).unsqueeze(0)
with torch.no_grad():
    fake_B = G_A_to_B(real_A, condition_A_to_B)
fake_B = fake_B.cpu().numpy()[0]  # Shape: (3, 64, 64)

plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.title("Generated Axial")
plt.imshow(fake_B[0], cmap='gray')
plt.axis('off')
plt.subplot(1, 3, 2)
plt.title("Generated Coronal")
plt.imshow(fake_B[1], cmap='gray')
plt.axis('off')
plt.subplot(1, 3, 3)
plt.title("Generated Sagittal")
plt.imshow(fake_B[2], cmap='gray')
plt.axis('off')
plt.tight_layout()
plt.savefig('/kaggle/working/generated_slices.png')
plt.show()
plt.close()

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import os
import random
import matplotlib.pyplot as plt
import nibabel as nib

# Kiểm tra GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Thiết bị đang sử dụng: {device}")

# Định nghĩa Generator (khớp với mô hình CycleGAN đã huấn luyện)
class Generator(nn.Module):
    def __init__(self, condition_dim=4):
        super(Generator, self).__init__()
        self.condition_dim = condition_dim
        self.condition_layer = nn.Sequential(
            nn.Linear(condition_dim, 64),
            nn.ReLU(),
        )
        self.encoder = nn.Sequential(
            nn.Conv2d(4, 64, kernel_size=4, stride=2, padding=1),  # Input: 3 kênh ảnh + 1 kênh condition
            nn.LeakyReLU(0.2),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2),
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1),  # Output: 3 kênh (axial, coronal, sagittal)
            nn.Tanh(),
        )
    
    def forward(self, x, condition):
        batch_size = x.size(0)
        condition = condition[:batch_size]
        condition = self.condition_layer(condition)
        condition = condition.view(batch_size, 1, 64, 1).expand(batch_size, 1, 64, 64)
        x = torch.cat([x, condition], dim=1)  # Shape: (batch_size, 4, 64, 64)
        x = self.encoder(x)
        x = self.decoder(x)  # Shape: (batch_size, 3, 64, 64)
        return x

# Tải dữ liệu
participants_file = "/kaggle/working/processed_mri_slices/participants.xlsx"
preprocessed_dir = "/kaggle/working/processed_mri_slices"

# Đọc thông tin subject từ participants.xlsx
participants_df = pd.read_excel(participants_file)
subject_info = {}
for _, row in participants_df.iterrows():
    subject_id = row['subject_id']
    subject_info[subject_id] = {
        'age': float(row['subject_age']),
        'gender': 1 if row['subject_sex'] == 'm' else 0
    }

# Lấy danh sách subject
all_subjects = [d for d in os.listdir(preprocessed_dir) if os.path.isdir(os.path.join(preprocessed_dir, d)) and d.startswith('sub-BrainAge')]
print(f"Tổng số subject: {len(all_subjects)}")

# Chuẩn hóa tuổi
max_age = 100

# Hàm tải và xử lý ảnh
def load_and_process_image(subject_id, preprocessed_dir):
    anat_dir = os.path.join(preprocessed_dir, subject_id, "anat")
    axial_slice = nib.load(os.path.join(anat_dir, f"{subject_id}_T1w_axial.nii.gz")).get_fdata()[0]  # Shape: (64, 64)
    coronal_slice = nib.load(os.path.join(anat_dir, f"{subject_id}_T1w_coronal.nii.gz")).get_fdata()[0]
    sagittal_slice = nib.load(os.path.join(anat_dir, f"{subject_id}_T1w_sagittal.nii.gz")).get_fdata()[0]
    
    combined_slice = np.stack([axial_slice, coronal_slice, sagittal_slice], axis=0)  # Shape: (3, 64, 64)
    combined_tensor = torch.tensor(combined_slice, dtype=torch.float32).unsqueeze(0).to(device)  # Shape: (1, 3, 64, 64)
    
    age = subject_info[subject_id]['age'] / max_age
    gender = subject_info[subject_id]['gender']
    condition = torch.tensor([age, gender], dtype=torch.float32).unsqueeze(0).to(device)  # Shape: (1, 2)
    
    return combined_slice, combined_tensor, condition, age * max_age, gender

# Tải mô hình
G_A_to_B = Generator().to(device)
G_A_to_B.eval()

model_path = "/kaggle/working/G_A_to_B_epoch_399_batch_0.pth"  # Điều chỉnh epoch/batch nếu cần
print(f"Tải mô hình từ: {model_path}")
if os.path.exists(model_path):
    G_A_to_B.load_state_dict(torch.load(model_path))
else:
    raise FileNotFoundError(f"Không tìm thấy file mô hình tại {model_path}")

# Chọn ngẫu nhiên 3 subject để kiểm tra
test_subjects = random.sample(all_subjects, 3)

# Các giá trị tuổi và giới tính mục tiêu để kiểm tra
target_conditions = [
    (25, 1),  # Tuổi 25, nam
    (25, 0),  # Tuổi 60, nữ
    (50,1),
    (50,0)
]

# Kiểm tra từng subject
for subject_id in test_subjects:
    # Tải ảnh và thông tin gốc
    real_A_np, real_A_tensor, condition_A, orig_age, orig_gender = load_and_process_image(subject_id, preprocessed_dir)
    real_A_np = (real_A_np + 1) / 2  # Chuyển từ [-1, 1] về [0, 1] để hiển thị
    
    # Hiển thị ảnh gốc
    print(f"\nSubject: {subject_id}")
    print(f"Tuổi gốc: {orig_age:.1f}, Giới tính gốc: {'Nam' if orig_gender == 1 else 'Nữ'}")
    
    fig, axes = plt.subplots(1, 3, figsize=(12, 4))
    for i, plane in enumerate(['Axial', 'Coronal', 'Sagittal']):
        axes[i].imshow(real_A_np[i], cmap='gray')
        axes[i].set_title(f"{plane} (Original)")
        axes[i].axis('off')
    plt.suptitle(f"Subject {subject_id} - Original Image")
    plt.show()
    
    # Kiểm tra với từng điều kiện mục tiêu
    for target_age, target_gender in target_conditions:
        target_age_normalized = target_age / max_age
        condition_A_to_B = torch.tensor([
            condition_A[0, 0].item(),  # Tuổi gốc
            condition_A[0, 1].item(),  # Giới tính gốc
            target_age_normalized,     # Tuổi đích
            target_gender              # Giới tính đích
        ], dtype=torch.float32).unsqueeze(0).to(device)  # Shape: (1, 4)
        
        # Sinh ảnh giả
        with torch.no_grad():
            fake_B = G_A_to_B(real_A_tensor, condition_A_to_B)  # Shape: (1, 3, 64, 64)
        
        # Chuyển tensor thành numpy để hiển thị
        fake_B_np = fake_B.squeeze(0).cpu().numpy()  # Shape: (3, 64, 64)
        fake_B_np = (fake_B_np + 1) / 2  # Chuyển từ [-1, 1] về [0, 1]
        
        # Hiển thị ảnh sinh ra
        print(f"Target: Tuổi đích {target_age}, Giới tính đích {'Nam' if target_gender == 1 else 'Nữ'}")
        fig, axes = plt.subplots(1, 3, figsize=(12, 4))
        for i, plane in enumerate(['Axial', 'Coronal', 'Sagittal']):
            axes[i].imshow(fake_B_np[i], cmap='gray')
            axes[i].set_title(f"{plane} (Generated)")
            axes[i].axis('off')
        plt.suptitle(f"Subject {subject_id} - Target: Age {target_age}, {'Nam' if target_gender == 1 else 'Nữ'}")
        plt.show()

print("\nHoàn thành kiểm tra.")
# Out:
# Thiết bị đang sử dụng: cuda
# Tổng số subject: 3000
# Tải mô hình từ: /kaggle/working/G_A_to_B_epoch_399_batch_0.pth
#
# Subject: sub-BrainAge005472
# Tuổi gốc: 45.7, Giới tính gốc: Nam
# /tmp/ipykernel_31/2063367579.py:94: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   G_A_to_B.load_state_dict(torch.load(model_path))
# Target: Tuổi đích 25, Giới tính đích Nam
# Target: Tuổi đích 25, Giới tính đích Nữ
# Target: Tuổi đích 50, Giới tính đích Nam
# Target: Tuổi đích 50, Giới tính đích Nữ
# Subject: sub-BrainAge005721
# Tuổi gốc: 21.0, Giới tính gốc: Nam
# Target: Tuổi đích 25, Giới tính đích Nam
# Target: Tuổi đích 25, Giới tính đích Nữ
# Target: Tuổi đích 50, Giới tính đích Nam
# Target: Tuổi đích 50, Giới tính đích Nữ
# Subject: sub-BrainAge020123
# Tuổi gốc: 54.2, Giới tính gốc: Nữ
# Target: Tuổi đích 25, Giới tính đích Nam
# Target: Tuổi đích 25, Giới tính đích Nữ
# Target: Tuổi đích 50, Giới tính đích Nam
# Target: Tuổi đích 50, Giới tính đích Nữ
# Hoàn thành kiểm tra.

# %%
import os
import shutil
import nibabel as nib
import numpy as np
import pandas as pd

# Đường dẫn
data_dir = "/kaggle/working/data_processed"
output_base_dir = "/kaggle/working/processed_mri_slices_128"
participants_file = os.path.join(data_dir, "participants.xlsx")

# Hàm tiền xử lý ảnh 2D
def preprocess_mri_slice(mri_slice):
    # Intensity normalization về [0, 1]
    mri_normalized = (mri_slice - mri_slice.min()) / (mri_slice.max() - mri_slice.min() + 1e-8)  # Tránh chia cho 0
    return mri_normalized

# Tạo danh sách file
file_list = []
for subject_id in os.listdir(data_dir):
    if subject_id.startswith('sub-BrainAge'):
        subject_dir = os.path.join(data_dir, subject_id, "anat")
        file_path = os.path.join(subject_dir, f"{subject_id}_T1w_processed.nii.gz")
        if os.path.exists(file_path):
            file_list.append(file_path)

# Kiểm tra file_list
if not file_list:
    raise ValueError("Không tìm thấy file nào khớp với mẫu *_T1w_processed.nii.gz trong thư mục data_processed!")

# Tạo thư mục đầu ra
os.makedirs(output_base_dir, exist_ok=True)
shutil.copy(participants_file, os.path.join(output_base_dir, "participants.xlsx"))

# Xử lý và lưu 3 mặt cắt 128x128
for idx, file_path in enumerate(file_list):
    subject_id = os.path.basename(os.path.dirname(os.path.dirname(file_path)))
    subject_output_dir = os.path.join(output_base_dir, subject_id, "anat")
    os.makedirs(subject_output_dir, exist_ok=True)
    
    # Đọc ảnh 3D
    mri_img = nib.load(file_path)
    mri_data = mri_img.get_fdata()  # Shape: (130, 130, 130)
    
    # Kiểm tra shape
    if mri_data.shape != (130, 130, 130):
        print(f"Cảnh báo: File {file_path} có shape {mri_data.shape}, không phải (130, 130, 130)")
        continue
    
    # Lấy 3 mặt cắt giữa
    axial_idx = mri_data.shape[2] // 2
    coronal_idx = mri_data.shape[1] // 2
    sagittal_idx = mri_data.shape[0] // 2
    
    axial_slice = mri_data[:, :, axial_idx]  # Shape: (130, 130)
    coronal_slice = mri_data[:, coronal_idx, :]  # Shape: (130, 130)
    sagittal_slice = mri_data[sagittal_idx, :, :]  # Shape: (130, 130)
    
    # Cắt 1 pixel mỗi chiều
    axial_slice = axial_slice[1:-1, 1:-1]  # Shape: (128, 128)
    coronal_slice = coronal_slice[1:-1, 1:-1]
    sagittal_slice = sagittal_slice[1:-1, 1:-1]
    
    # Tiền xử lý
    axial_normalized = preprocess_mri_slice(axial_slice)
    coronal_normalized = preprocess_mri_slice(coronal_slice)
    sagittal_normalized = preprocess_mri_slice(sagittal_slice)
    
    # Chuẩn hóa về [-1, 1]
    axial_final = axial_normalized * 2 - 1
    coronal_final = coronal_normalized * 2 - 1
    sagittal_final = sagittal_normalized * 2 - 1
    
    # Lưu 3 mặt cắt
    for slice_type, slice_data in [
        ('axial', axial_final),
        ('coronal', coronal_final),
        ('sagittal', sagittal_final)
    ]:
        output_file = os.path.join(subject_output_dir, f"{subject_id}_T1w_{slice_type}.nii.gz")
        slice_data_3d = slice_data[np.newaxis, :, :]  # Shape: (1, 128, 128)
        nib.save(nib.Nifti1Image(slice_data_3d, np.eye(4)), output_file)
    

print(f"Đã lưu tất cả dữ liệu 128x128 vào: {output_base_dir}")
# Out:
# Đã lưu tất cả dữ liệu 128x128 vào: /kaggle/working/processed_mri_slices_128

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import os
import nibabel as nib
import pandas as pd
import time
import matplotlib.pyplot as plt

# Kiểm tra GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Thiết bị đang sử dụng: {device}")

# Dataset cho super-resolution
class SRDataset(Dataset):
    def __init__(self, lr_dir, hr_dir, subjects, target_shape_lr=(64, 64), target_shape_hr=(128, 128)):
        self.lr_dir = lr_dir  # Thư mục ảnh 64x64
        self.hr_dir = hr_dir  # Thư mục ảnh 128x128
        self.subjects = subjects
        self.target_shape_lr = target_shape_lr
        self.target_shape_hr = target_shape_hr
    
    def __len__(self):
        return len(self.subjects)
    
    def __getitem__(self, idx):
        subject_id = self.subjects[idx]
        lr_subject_dir = os.path.join(self.lr_dir, subject_id, "anat")
        hr_subject_dir = os.path.join(self.hr_dir, subject_id, "anat")
        
        # Đọc 3 mặt cắt 64x64 (low-resolution)
        lr_slices = []
        for slice_type in ['axial', 'coronal', 'sagittal']:
            file_path = os.path.join(lr_subject_dir, f"{subject_id}_T1w_{slice_type}.nii.gz")
            mri_img = nib.load(file_path)
            mri_data = mri_img.get_fdata()[0]  # Shape: (64, 64)
            lr_slices.append(mri_data)
        lr_tensor = torch.tensor(np.stack(lr_slices), dtype=torch.float32)  # Shape: (3, 64, 64)
        
        # Đọc 3 mặt cắt 128x128 (high-resolution)
        hr_slices = []
        for slice_type in ['axial', 'coronal', 'sagittal']:
            file_path = os.path.join(hr_subject_dir, f"{subject_id}_T1w_{slice_type}.nii.gz")
            mri_img = nib.load(file_path)
            mri_data = mri_img.get_fdata()[0]  # Shape: (128, 128)
            hr_slices.append(mri_data)
        hr_tensor = torch.tensor(np.stack(hr_slices), dtype=torch.float32)  # Shape: (3, 128, 128)
        
        return lr_tensor, hr_tensor

# Mô hình SRResNet
class SRResNet(nn.Module):
    def __init__(self, num_residual_blocks=8):
        super(SRResNet, self).__init__()
        
        # Initial convolution
        self.initial = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=9, stride=1, padding=4),
            nn.PReLU(),
        )
        
        # Residual blocks
        self.res_blocks = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
                nn.BatchNorm2d(64),
                nn.PReLU(),
                nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
                nn.BatchNorm2d(64),
            ) for _ in range(num_residual_blocks)
        ])
        
        # Post-residual convolution
        self.post_res = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
        )
        
        # Upsampling (64x64 -> 128x128)
        self.upsample = nn.Sequential(
            nn.Conv2d(64, 256, kernel_size=3, stride=1, padding=1),
            nn.PixelShuffle(upscale_factor=2),  # 64x64 -> 128x128
            nn.PReLU(),
        )
        
        # Final convolution
        self.final = nn.Conv2d(64, 3, kernel_size=9, stride=1, padding=4)
    
    def forward(self, x):
        # Initial feature extraction
        x = self.initial(x)
        
        # Residual blocks
        residual = x
        for res_block in self.res_blocks:
            x = res_block(x) + x  # Skip connection
        x = self.post_res(x) + residual
        
        # Upsampling
        x = self.upsample(x)
        
        # Final output
        x = self.final(x)
        return torch.tanh(x)  # Đầu ra [-1, 1]

# Tạo danh sách subjects
lr_dir = "/kaggle/working/processed_mri_slices"
hr_dir = "/kaggle/working/processed_mri_slices_128"
subjects = [s for s in os.listdir(lr_dir) if s.startswith('sub-BrainAge')]

# Tạo Dataset và DataLoader
dataset = SRDataset(lr_dir, hr_dir, subjects)
dataloader = DataLoader(dataset, batch_size=16, shuffle=True, num_workers=0, pin_memory=True)

# Khởi tạo mô hình
model = SRResNet().to(device)

# Loss function và optimizer
criterion = nn.L1Loss()
optimizer = optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999))

# Mixed precision
scaler = torch.amp.GradScaler('cuda')

# Huấn luyện
epochs = 100
for epoch in range(epochs):
    losses = []
    num_batches = 0
    data_time = 0
    model_time = 0
    
    for i, (lr_images, hr_images) in enumerate(dataloader):
        start_time = time.time()
        lr_images = lr_images.to(device)  # Shape: (batch_size, 3, 64, 64)
        hr_images = hr_images.to(device)  # Shape: (batch_size, 3, 128, 128)
        data_time += time.time() - start_time
        
        optimizer.zero_grad()
        
        model_start = time.time()
        with torch.amp.autocast('cuda'):
            sr_images = model(lr_images)  # Shape: (batch_size, 3, 128, 128)
            loss = criterion(sr_images, hr_images)
        
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        model_time += time.time() - model_start
        
        losses.append(loss.item())
        num_batches += 1
        
        if i % 100 == 0:
            torch.save(model.state_dict(), f"/kaggle/working/sr_model_epoch_{epoch}_batch_{i}.pth")
            print(f"Batch {i}, Data time: {data_time:.2f}s, Model time: {model_time:.2f}s, VRAM: {torch.cuda.memory_allocated() / 1024**2:.2f}MB, Loss: {loss.item():.4f}")
    
    avg_loss = sum(losses) / num_batches if num_batches > 0 else 0
    print(f"Epoch {epoch+1}, Avg Loss: {avg_loss:.4f}")

# Vẽ kết quả mẫu
lr_images, hr_images = dataset[0]
lr_images = lr_images.unsqueeze(0).to(device)
hr_images = hr_images.unsqueeze(0).to(device)
with torch.no_grad():
    sr_images = model(lr_images)
sr_images = sr_images.cpu().numpy()[0]  # Shape: (3, 128, 128)
hr_images = hr_images.cpu().numpy()[0]  # Shape: (3, 128, 128)
lr_images = lr_images.cpu().numpy()[0]  # Shape: (3, 64, 64)

plt.figure(figsize=(15, 15))
for j, title in enumerate(["Axial", "Coronal", "Sagittal"]):
    # Low-resolution
    plt.subplot(3, 3, j+1)
    plt.title(f"LR {title} (64x64)")
    plt.imshow(lr_images[j], cmap='gray')
    plt.axis('off')
    # Super-resolution
    plt.subplot(3, 3, j+4)
    plt.title(f"SR {title} (128x128)")
    plt.imshow(sr_images[j], cmap='gray')
    plt.axis('off')
    # High-resolution
    plt.subplot(3, 3, j+7)
    plt.title(f"HR {title} (128x128)")
    plt.imshow(hr_images[j], cmap='gray')
    plt.axis('off')
plt.tight_layout()
plt.savefig('/kaggle/working/sr_sample.png')
plt.show()
plt.close()
# Out:
# Thiết bị đang sử dụng: cuda
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.8666
# Batch 100, Data time: 0.05s, Model time: 6.87s, VRAM: 113.38MB, Loss: 0.0637
# Epoch 1, Avg Loss: 0.0937
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0544
# Batch 100, Data time: 0.05s, Model time: 6.75s, VRAM: 113.38MB, Loss: 0.0446
# Epoch 2, Avg Loss: 0.0468
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0450
# Batch 100, Data time: 0.05s, Model time: 6.75s, VRAM: 113.38MB, Loss: 0.0376
# Epoch 3, Avg Loss: 0.0409
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0383
# Batch 100, Data time: 0.05s, Model time: 6.74s, VRAM: 113.38MB, Loss: 0.0378
# Epoch 4, Avg Loss: 0.0385
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0372
# Batch 100, Data time: 0.05s, Model time: 6.74s, VRAM: 113.38MB, Loss: 0.0351
# Epoch 5, Avg Loss: 0.0367
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0365
# Batch 100, Data time: 0.05s, Model time: 6.74s, VRAM: 113.38MB, Loss: 0.0376
# Epoch 6, Avg Loss: 0.0357
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0330
# Batch 100, Data time: 0.05s, Model time: 6.74s, VRAM: 113.38MB, Loss: 0.0323
# Epoch 7, Avg Loss: 0.0351
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0371
# Batch 100, Data time: 0.05s, Model time: 6.74s, VRAM: 113.38MB, Loss: 0.0365
# Epoch 8, Avg Loss: 0.0344
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0328
# Batch 100, Data time: 0.05s, Model time: 6.74s, VRAM: 113.38MB, Loss: 0.0365
# Epoch 9, Avg Loss: 0.0338
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0308
# Batch 100, Data time: 0.05s, Model time: 6.75s, VRAM: 113.38MB, Loss: 0.0323
# Epoch 10, Avg Loss: 0.0334
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0339
# Batch 100, Data time: 0.05s, Model time: 6.75s, VRAM: 113.38MB, Loss: 0.0349
# Epoch 11, Avg Loss: 0.0331
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0327
# Batch 100, Data time: 0.05s, Model time: 6.75s, VRAM: 113.38MB, Loss: 0.0306
# Epoch 12, Avg Loss: 0.0326
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0308
# Batch 100, Data time: 0.05s, Model time: 6.75s, VRAM: 113.38MB, Loss: 0.0313
# Epoch 13, Avg Loss: 0.0323
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0336
# Batch 100, Data time: 0.05s, Model time: 6.75s, VRAM: 113.38MB, Loss: 0.0322
# Epoch 14, Avg Loss: 0.0319
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0321
# Batch 100, Data time: 0.05s, Model time: 6.74s, VRAM: 113.38MB, Loss: 0.0313
# Epoch 15, Avg Loss: 0.0318
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0324
# Batch 100, Data time: 0.05s, Model time: 6.74s, VRAM: 113.38MB, Loss: 0.0307
# Epoch 16, Avg Loss: 0.0314
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0302
# Batch 100, Data time: 0.05s, Model time: 6.74s, VRAM: 113.38MB, Loss: 0.0327
# Epoch 17, Avg Loss: 0.0312
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0293
# Batch 100, Data time: 0.05s, Model time: 6.74s, VRAM: 113.38MB, Loss: 0.0318
# Epoch 18, Avg Loss: 0.0309
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0310
# Batch 100, Data time: 0.05s, Model time: 6.74s, VRAM: 113.38MB, Loss: 0.0303
# Epoch 19, Avg Loss: 0.0307
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0324
# Batch 100, Data time: 0.05s, Model time: 6.74s, VRAM: 113.38MB, Loss: 0.0283
# Epoch 20, Avg Loss: 0.0304
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0313
# Batch 100, Data time: 0.05s, Model time: 6.75s, VRAM: 113.38MB, Loss: 0.0268
# Epoch 21, Avg Loss: 0.0302
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0285
# Batch 100, Data time: 0.05s, Model time: 6.75s, VRAM: 113.38MB, Loss: 0.0329
# Epoch 22, Avg Loss: 0.0299
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0297
# Batch 100, Data time: 0.05s, Model time: 6.75s, VRAM: 113.38MB, Loss: 0.0295
# Epoch 23, Avg Loss: 0.0298
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0295
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0295
# Epoch 24, Avg Loss: 0.0296
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0308
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0276
# Epoch 25, Avg Loss: 0.0294
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0268
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0306
# Epoch 26, Avg Loss: 0.0292
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0306
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0271
# Epoch 27, Avg Loss: 0.0291
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0292
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0280
# Epoch 28, Avg Loss: 0.0289
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0292
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0287
# Epoch 29, Avg Loss: 0.0288
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0279
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0288
# Epoch 30, Avg Loss: 0.0286
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0283
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0276
# Epoch 31, Avg Loss: 0.0284
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0289
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0287
# Epoch 32, Avg Loss: 0.0284
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0291
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0265
# Epoch 33, Avg Loss: 0.0283
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0283
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0278
# Epoch 34, Avg Loss: 0.0281
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0274
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0295
# Epoch 35, Avg Loss: 0.0281
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0269
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0289
# Epoch 36, Avg Loss: 0.0279
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0287
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0276
# Epoch 37, Avg Loss: 0.0278
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0277
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0273
# Epoch 38, Avg Loss: 0.0277
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0270
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0293
# Epoch 39, Avg Loss: 0.0276
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0279
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0257
# Epoch 40, Avg Loss: 0.0276
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0274
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0283
# Epoch 41, Avg Loss: 0.0274
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0271
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0268
# Epoch 42, Avg Loss: 0.0274
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0270
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0287
# Epoch 43, Avg Loss: 0.0273
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0267
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0290
# Epoch 44, Avg Loss: 0.0272
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0283
# Batch 100, Data time: 0.05s, Model time: 6.75s, VRAM: 113.38MB, Loss: 0.0263
# Epoch 45, Avg Loss: 0.0271
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0292
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0262
# Epoch 46, Avg Loss: 0.0270
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0285
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0290
# Epoch 47, Avg Loss: 0.0270
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0261
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0288
# Epoch 48, Avg Loss: 0.0269
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0265
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0293
# Epoch 49, Avg Loss: 0.0269
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0258
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0261
# Epoch 50, Avg Loss: 0.0268
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0299
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0281
# Epoch 51, Avg Loss: 0.0267
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0258
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0263
# Epoch 52, Avg Loss: 0.0267
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0257
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0270
# Epoch 53, Avg Loss: 0.0266
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0256
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0296
# Epoch 54, Avg Loss: 0.0266
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0255
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0260
# Epoch 55, Avg Loss: 0.0265
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0250
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0253
# Epoch 56, Avg Loss: 0.0264
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0268
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0252
# Epoch 57, Avg Loss: 0.0264
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0272
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0255
# Epoch 58, Avg Loss: 0.0264
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0277
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0247
# Epoch 59, Avg Loss: 0.0263
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0262
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0250
# Epoch 60, Avg Loss: 0.0262
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0275
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0264
# Epoch 61, Avg Loss: 0.0262
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0270
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0242
# Epoch 62, Avg Loss: 0.0261
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0249
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0266
# Epoch 63, Avg Loss: 0.0261
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0274
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0228
# Epoch 64, Avg Loss: 0.0261
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0279
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0264
# Epoch 65, Avg Loss: 0.0260
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0253
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0248
# Epoch 66, Avg Loss: 0.0260
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0261
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0245
# Epoch 67, Avg Loss: 0.0259
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0276
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0264
# Epoch 68, Avg Loss: 0.0259
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0276
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0264
# Epoch 69, Avg Loss: 0.0258
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0244
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0260
# Epoch 70, Avg Loss: 0.0258
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0242
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0272
# Epoch 71, Avg Loss: 0.0257
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0274
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0247
# Epoch 72, Avg Loss: 0.0257
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0247
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0254
# Epoch 73, Avg Loss: 0.0257
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0277
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0238
# Epoch 74, Avg Loss: 0.0256
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0249
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0245
# Epoch 75, Avg Loss: 0.0256
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0268
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0260
# Epoch 76, Avg Loss: 0.0255
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0255
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0263
# Epoch 77, Avg Loss: 0.0255
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0251
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0284
# Epoch 78, Avg Loss: 0.0255
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0241
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0257
# Epoch 79, Avg Loss: 0.0255
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0274
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0256
# Epoch 80, Avg Loss: 0.0254
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0248
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0244
# Epoch 81, Avg Loss: 0.0254
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0257
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0277
# Epoch 82, Avg Loss: 0.0254
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0253
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0257
# Epoch 83, Avg Loss: 0.0253
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0270
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0242
# Epoch 84, Avg Loss: 0.0253
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0256
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0254
# Epoch 85, Avg Loss: 0.0253
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0260
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0246
# Epoch 86, Avg Loss: 0.0252
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0250
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0248
# Epoch 87, Avg Loss: 0.0252
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0261
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0238
# Epoch 88, Avg Loss: 0.0251
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0258
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0268
# Epoch 89, Avg Loss: 0.0251
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0247
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0248
# Epoch 90, Avg Loss: 0.0251
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0238
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0246
# Epoch 91, Avg Loss: 0.0251
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0254
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0239
# Epoch 92, Avg Loss: 0.0250
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0259
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0254
# Epoch 93, Avg Loss: 0.0250
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0228
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0236
# Epoch 94, Avg Loss: 0.0250
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0247
# Batch 100, Data time: 0.05s, Model time: 6.78s, VRAM: 113.38MB, Loss: 0.0236
# Epoch 95, Avg Loss: 0.0249
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0240
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0251
# Epoch 96, Avg Loss: 0.0249
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0253
# Batch 100, Data time: 0.05s, Model time: 6.77s, VRAM: 113.38MB, Loss: 0.0245
# Epoch 97, Avg Loss: 0.0249
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0245
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0249
# Epoch 98, Avg Loss: 0.0249
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0258
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0251
# Epoch 99, Avg Loss: 0.0249
# Batch 0, Data time: 0.00s, Model time: 0.07s, VRAM: 113.50MB, Loss: 0.0262
# Batch 100, Data time: 0.05s, Model time: 6.76s, VRAM: 113.38MB, Loss: 0.0232
# Epoch 100, Avg Loss: 0.0248

# %%
# Vẽ kết quả mẫu
lr_images, hr_images = dataset[0]
lr_images = lr_images.unsqueeze(0).to(device)
hr_images = hr_images.unsqueeze(0).to(device)
with torch.no_grad():
    sr_images = model(lr_images)
sr_images = sr_images.cpu().numpy()[0]  # Shape: (3, 128, 128)
hr_images = hr_images.cpu().numpy()[0]  # Shape: (3, 128, 128)
lr_images = lr_images.cpu().numpy()[0]  # Shape: (3, 64, 64)

plt.figure(figsize=(15, 15))
for j, title in enumerate(["Axial", "Coronal", "Sagittal"]):
    # Low-resolution
    plt.subplot(3, 3, j+1)
    plt.title(f"LR {title} (64x64)")
    plt.imshow(lr_images[j], cmap='gray')
    plt.axis('off')
    # Super-resolution
    plt.subplot(3, 3, j+4)
    plt.title(f"SR {title} (128x128)")
    plt.imshow(sr_images[j], cmap='gray')
    plt.axis('off')
    # High-resolution
    plt.subplot(3, 3, j+7)
    plt.title(f"HR {title} (128x128)")
    plt.imshow(hr_images[j], cmap='gray')
    plt.axis('off')
plt.tight_layout()
plt.savefig('/kaggle/working/sr_sample.png')
plt.show()
plt.close()
